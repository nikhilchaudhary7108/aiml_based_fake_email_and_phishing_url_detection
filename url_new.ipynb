# %%
pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\lenovo\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (2.1.3)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\lenovo\anaconda3\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset

ds = load_dataset("kmack/Phishing_urls")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 567056
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 70882
#     })
#     valid: Dataset({
#         features: ['text', 'label'],
#         num_rows: 70882
#     })
# })

# %%
train_df = ds['train'].to_pandas()

# %%
test_df = ds['test'].to_pandas()
valid_df = ds['valid'].to_pandas()

# %%
print(train_df.head(),test_df.head(),valid_df.head())
# Out:
#                                                 text  label
# 0             xenophongroup.com/montjoie/compgns.htm      0
# 1    www.azzali.eu/&usg=AOvVaw2phVSb_ENMrkATGNx5LQ0l      1
# 2                     guildmusic.edu.au/js/index.htm      1
# 3  memo.unexpectedrunner.com/ezxgytw4et\nholotili...      1
# 4  en.wikipedia.org/wiki/Category:American_televi...      0                                                 text  label
# 0    www.linuxplanet.com/linuxplanet/reviews/4149/1/      1
# 1  sdnmargorejo1-403.sch.id/images/login.alibaba....      1
# 2  '9d345009-a-62cb3a1a-s-sites.googlegroups.com/...      0
# 3            everyculture.com/Ma-Ni/New-Zealand.html      0
# 4                    www.aoseocn.acseosn.selfie.ltd/      1                                                 text  label
# 0       absoluteastronomy.com/topics/Sri_Lankan_Navy      0
# 1                    www.angelfire.com/amiga/grotto/      1
# 2  www.etc-meisai.jp.lmxnzp.shop/kaduxn.php?lia71...      1
# 3  http://torcache.net/torrent/DCA42EC92836BAC652...      0
# 4                                shanghaitaihong.cn/      1

# %% [markdown]
# verifying data leakage prevention

# %%
import pandas as pd

# assuming you have 'id' or can hash rows
train_hashes = set(train_df.apply(lambda x: hash(tuple(x)), axis=1))
test_hashes = set(test_df.apply(lambda x: hash(tuple(x)), axis=1))
valid_hashes = set(valid_df.apply(lambda x: hash(tuple(x)), axis=1))

print("Train-Test overlap:", len(train_hashes & test_hashes))
print("Train-Valid overlap:", len(train_hashes & valid_hashes))
print("Test-Valid overlap:", len(test_hashes & valid_hashes))
# Out:
# Train-Test overlap: 0
# Train-Valid overlap: 0
# Test-Valid overlap: 0

# %%
print("Shape of the training dataset is :",train_df.shape)
print("No. of missing values :",train_df.isnull().sum())
print("Duplicate values in urls:",train_df["text"].duplicated().sum())
print("Number of unique values : ",train_df.nunique())
# Out:
# Shape of the training dataset is : (567056, 2)
# No. of missing values : text     0
# label    0
# dtype: int64
# Duplicate values in urls: 31218
# Number of unique values :  text     535838
# label         2
# dtype: int64

# %%
train_df = train_df.drop_duplicates(subset = "text")

# %%
print("Duplicate values in urls:",train_df["text"].duplicated().sum())
# Out:
# Duplicate values in urls: 0

# %% [markdown]
# Tokenization

# %%
import re

def clean_url(url):
    url = url.lower().strip()

    # Remove protocol but keep subdomains
    url = re.sub(r'^https?://', '', url)

    # Remove trailing slashes and fragments (#, etc.)
    url = re.sub(r'[#]+.*', '', url)
    
    # Remove common tracking parameters (optional)
    url = re.sub(r'(\?|&)(utm_[^=]+|fbclid|gclid)=[^&]+', '', url)

    # Remove non-useful symbols, but keep . / ? = _ - &
    url = re.sub(r'[^a-z0-9./?=&_-]', '', url)

    # Replace multiple slashes with one (to avoid //)
    url = re.sub(r'/+', '/', url)

    return url

# %%
train_df['text'] = train_df['text'].apply(clean_url)
valid_df['text'] = valid_df['text'].apply(clean_url)
test_df['text'] = test_df['text'].apply(clean_url)

# %%
train_df.shape
# Out:
# (535838, 2)

# %%
train_df.duplicated().sum()
# Out:
# np.int64(9575)

# %%
train_df.shape
# Out:
# (535838, 2)

# %%
train_df = train_df.drop_duplicates(subset = "text")

# %%
train_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
url_lengths = train_df['text'].apply(len)
print(url_lengths.describe())
# Out:
# count    525364.000000
# mean         46.736122
# std          46.452726
# min           0.000000
# 25%          21.000000
# 50%          34.000000
# 75%          56.000000
# max        2307.000000
# Name: text, dtype: float64

# %%
import numpy as np
maxlen = int(np.percentile(url_lengths, 98))
print("Chosen maxlen:", maxlen)
# Out:
# Chosen maxlen: 182

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\lenovo\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\lenovo\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\lenovo\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\lenovo\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Build a character-level tokenizer
tokenizer = Tokenizer(char_level=True, lower=True, filters='')  # keep special chars
tokenizer.fit_on_texts(train_df['text'])

# Convert to sequences
X_train_seq = tokenizer.texts_to_sequences(train_df['text'])
X_val_seq   = tokenizer.texts_to_sequences(valid_df['text'])
X_test_seq  = tokenizer.texts_to_sequences(test_df['text'])

# Padding to a fixed length
maxlen = maxlen  # adjust based on URL length distribution
X_train_pad = pad_sequences(X_train_seq, maxlen=maxlen, padding='post')
X_val_pad   = pad_sequences(X_val_seq, maxlen=maxlen, padding='post')
X_test_pad  = pad_sequences(X_test_seq, maxlen=maxlen, padding='post')

# Labels
y_train = train_df['label'].values
y_val   = valid_df['label'].values
y_test  = test_df['label'].values

# %%
print("Vocab size:", len(tokenizer.word_index) + 1)
print("Sample tokens:", list(tokenizer.word_index.keys())[:50])
# Out:
# Vocab size: 44
# Sample tokens: ['e', 'o', 'a', 'c', '.', 'i', 't', 's', 'n', '/', 'r', 'm', 'l', 'd', 'p', 'w', '-', 'u', 'h', 'b', 'g', 'f', '1', '0', '2', 'y', 'k', '3', '8', 'v', '5', '4', '9', '6', '7', 'x', 'j', '_', '=', 'z', 'q', '?', '&']

# %%
train_df
# Out:
#                                                      text  label
# 0                  xenophongroup.com/montjoie/compgns.htm      0
# 1         www.azzali.eu/&usg=aovvaw2phvsb_enmrkatgnx5lq0l      1
# 2                          guildmusic.edu.au/js/index.htm      1
# 3       memo.unexpectedrunner.com/ezxgytw4etnholotilic...      1
# 4       en.wikipedia.org/wiki/categoryamerican_televis...      0
# ...                                                   ...    ...
# 567049  ucdavisaggies.com/sports/m-footbl/mtt/allen_dr...      0
# 567050      www.aoscuu-smaocmeouusnauu.fhoarcu.museum.mw/      1
# 567051  www.en.wikipedia.org/wiki/charles_taylor_philo...      0
# 567054                                     revenue.ky.gov      0
# 567055               www.minutiaesoftware.com/reunion.htm      1
#
# [525364 rows x 2 columns]

# %%
X_train_pad.shape
# Out:
# (525364, 182)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\lenovo\anaconda3\lib\site-packages (3.1.1)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from xgboost) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Conv1D, MaxPooling1D, Concatenate, \
                                     BatchNormalization, ReLU, Bidirectional, LSTM, Dense, GlobalMaxPool1D
from tensorflow.keras.models import Model, clone_model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from copy import deepcopy

# %%
# Use your values
vocab_size = 44         # given
maxlen = 182            # given

# Model hyperparams (sensible defaults for URL data)
embedding_dim = 100      # smaller -> faster; increase to 100-200 if GPU and memory allow
conv_filters = 128
conv_kernel_sizes = [3,5,7]   # parallel convs capture tri/5/7-gram char patterns
pool_size = 2
bilstm_units = 128
dense_proj_units = 128   # final neural feature dimension to feed XGBoost

# Federated training hyperparams
num_clients = 10
federated_rounds = 5
local_epochs = 1        # keep small for FL experiments; increase later
batch_size = 256
learning_rate = 1e-3

# %%
def build_feature_extractor(vocab_size, maxlen,
                            embedding_dim=64,
                            conv_filters=128,
                            conv_kernel_sizes=[3,5,7],
                            pool_size=2,
                            bilstm_units=128,
                            dense_proj_units=128):
    inp = Input(shape=(maxlen,), dtype='int32', name='input_ids')
    x = Embedding(input_dim=vocab_size, output_dim=embedding_dim,
                  input_length=maxlen, mask_zero=False, name='embedding')(inp)
    # Parallel convs
    convs = []
    for k in conv_kernel_sizes:
        c = Conv1D(filters=conv_filters, kernel_size=k, padding='same')(x)
        c = BatchNormalization()(c)
        c = ReLU()(c)
        c = MaxPooling1D(pool_size=pool_size)(c)
        convs.append(c)
    x = Concatenate(axis=-1)(convs)  # shape: (batch, reduced_len, conv_filters*len(k))
    # Optional extra conv to mix channels
    x = Conv1D(filters=conv_filters, kernel_size=3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # BiLSTM for context; return_sequences=False to get a single vector per sample
    x = Bidirectional(LSTM(bilstm_units, return_sequences=False))(x)

    # Projection / fusion: compact vector for XGBoost. No final activation here.
    x = Dense(dense_proj_units, activation='relu', name='dense_proj')(x)
    # Note: don't apply dropout here because we want deterministic features for XGBoost
    model = Model(inputs=inp, outputs=x, name='cnn_bilstm_extractor')
    return model

# Build the model
feature_extractor = build_feature_extractor(vocab_size=vocab_size,
                                            maxlen=maxlen,
                                            embedding_dim=embedding_dim,
                                            conv_filters=conv_filters,
                                            conv_kernel_sizes=conv_kernel_sizes,
                                            pool_size=pool_size,
                                            bilstm_units=bilstm_units,
                                            dense_proj_units=dense_proj_units)
feature_extractor.summary()
# Out:
# c:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "cnn_bilstm_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_ids           │ (None, 182)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 182, 100)  │      4,400 │ input_ids[0][0]   │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 182, 128)  │     38,528 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 182, 128)  │     64,128 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 182, 128)  │     89,728 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 182, 128)  │        512 │ conv1d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 182, 128)  │        512 │ conv1d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 182, 128)  │        512 │ conv1d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 182, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 182, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 182, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_9     │ (None, 91, 128)   │          0 │ re_lu_12[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_10    │ (None, 91, 128)   │          0 │ re_lu_13[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_11    │ (None, 91, 128)   │          0 │ re_lu_14[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 91, 384)   │          0 │ max_pooling1d_9[… │
# │ (Concatenate)       │                   │            │ max_pooling1d_10… │
# │                     │                   │            │ max_pooling1d_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 91, 128)   │    147,584 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 91, 128)   │        512 │ conv1d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 91, 128)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 256)       │    263,168 │ re_lu_15[0][0]    │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_proj (Dense)  │ (None, 128)       │     32,896 │ bidirectional_3[… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 642,480 (2.45 MB)
#  Trainable params: 641,456 (2.45 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
feature_extractor.summary()
# Out:
# Model: "cnn_bilstm_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_ids           │ (None, 182)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 182, 100)  │      4,400 │ input_ids[0][0]   │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 182, 128)  │     38,528 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 182, 128)  │     64,128 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 182, 128)  │     89,728 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 182, 128)  │        512 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 182, 128)  │        512 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 182, 128)  │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 182, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 182, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 182, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 91, 128)   │          0 │ re_lu[0][0]       │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 91, 128)   │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 91, 128)   │          0 │ re_lu_2[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 91, 384)   │          0 │ max_pooling1d[0]… │
# │ (Concatenate)       │                   │            │ max_pooling1d_1[… │
# │                     │                   │            │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 91, 128)   │    147,584 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 91, 128)   │        512 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 91, 128)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 256)       │    263,168 │ re_lu_3[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_proj (Dense)  │ (None, 128)       │     32,896 │ bidirectional[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 642,480 (2.45 MB)
#  Trainable params: 641,456 (2.45 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
def compile_local_model(model, lr=1e-3):
    # Local training uses a temporary head for supervised training.
    # We'll attach a tiny classifier head for local training (binary classification),
    # then remove it for feature extraction.
    inp = model.input
    features = model.output
    out = Dense(1, activation='sigmoid', name='tmp_output')(features)
    train_model = Model(inputs=inp, outputs=out)
    train_model.compile(optimizer=Adam(lr), loss='binary_crossentropy', metrics=['accuracy'])
    return train_model

def get_model_weights(model):
    return model.get_weights()

def set_model_weights(model, weights):
    model.set_weights(weights)

def average_weights(weight_list):
    # simple element-wise average
    avg = []
    for weights in zip(*weight_list):
        avg.append(np.mean(weights, axis=0))
    return avg

# %%
def make_clients(X, y, num_clients):
    # simple IID split
    n = X.shape[0]
    indices = np.arange(n)
    np.random.shuffle(indices)
    splits = np.array_split(indices, num_clients)
    clients = [(X[s], y[s]) for s in splits]
    return clients

def federated_train(global_model, X_train, y_train,
                    num_clients=10,
                    rounds=5,
                    local_epochs=1,
                    batch_size=256,
                    lr=1e-3):
    # compile a local copy model with a temporary classifier head
    clients = make_clients(X_train, y_train, num_clients)
    # We'll hold global weights
    global_weights = get_model_weights(global_model)
    for r in range(rounds):
        print(f"\n=== Federated round {r+1}/{rounds} ===")
        local_weights = []
        for i, (X_c, y_c) in enumerate(clients):
            # create a fresh local train model from global extractor
            local_extractor = build_feature_extractor(vocab_size, maxlen,
                                                      embedding_dim, conv_filters,
                                                      conv_kernel_sizes, pool_size,
                                                      bilstm_units, dense_proj_units)
            # set global weights into local extractor
            set_model_weights(local_extractor, global_weights)
            # attach tiny head and compile
            local_train_model = compile_local_model(local_extractor, lr=lr)
            print(f" Client {i+1}: training on {X_c.shape[0]} samples")
            # Local training (small epochs)
            local_train_model.fit(X_c, y_c, epochs=local_epochs, batch_size=batch_size, verbose=1)
            # Extract updated extractor weights (strip off the tmp head)
            local_weights.append(get_model_weights(local_extractor))
            tf.keras.backend.clear_session()
        # Aggregate weights via FedAvg
        global_weights = average_weights(local_weights)
        # Set new global weights
        set_model_weights(global_model, global_weights)
        print(" Aggregated global weights updated.")
    return global_model

# Example usage:
# global_extractor = build_feature_extractor(...)
# trained_global_extractor = federated_train(global_extractor, X_train, y_train, ...)

# %%
# assume 'trained_global_extractor' is the returned model from federated_train
# or you can skip federated and just use the initial feature_extractor

def extract_features(extractor_model, X):
    # extractor_model outputs the dense feature vector (dense_proj)
    features = extract  or_model.predict(X, batch_size=512, verbose=1)
    return features

# %%
# Run federated training
trained_global_extractor = federated_train(
    global_model=feature_extractor,
    X_train=X_train_pad,
    y_train=y_train,
    num_clients=3,        # you can reduce to 5 to test faster
    rounds=3,              # start small; increase later
    local_epochs=2,
    batch_size=256,
    lr=1e-3
)
# Out:
# === Federated round 1/3 ===
# c:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
#  Client 1: training on 175122 samples
# Epoch 1/2
#   8/685 ━━━━━━━━━━━━━━━━━━━━ 7:24 656ms/step - accuracy: 0.5432 - loss: 0.6937
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Run federated training
# ----> 2 trained_global_extractor = federated_train(
#       3     global_model=feature_extractor,
#       4     X_train=X_train_pad,
#       5     y_train=y_train,
#       6     num_clients=3,        # you can reduce to 5 to test faster
#       7     rounds=3,              # start small; increase later
#       8     local_epochs=2,
#       9     batch_size=256,
#      10     lr=1e-3
#      11 )
#
# Cell In[28], line 35, in federated_train(global_model, X_train, y_train, num_clients, rounds, local_epochs, batch_size, lr)
#      33 print(f" Client {i+1}: training on {X_c.shape[0]} samples")
#      34 # Local training (small epochs)
# ---> 35 local_train_model.fit(X_c, y_c, epochs=local_epochs, batch_size=batch_size, verbose=1)
#      36 # Extract updated extractor weights (strip off the tmp head)
#      37 local_weights.append(get_model_weights(local_extractor))
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Extract features
X_train_feats = extract_features(trained_global_extractor, X_train_pad)
X_val_feats   = extract_features(trained_global_extractor, X_val_pad)
# Out:
# 1027/1027 ━━━━━━━━━━━━━━━━━━━━ 434s 422ms/step
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 56s 399ms/step

# %%
pip install -U xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\lenovo\anaconda3\lib\site-packages (3.1.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from xgboost) (1.15.3)

# %%
# Example: after federated training
# trained_global_extractor = federated_train(feature_extractor, X_train, y_train, ...)
# In case federated round is expensive, you can first try without FL:
# trained_global_extractor = feature_extractor  # pre-trained or untrained baseline

# 1) Extract features
# X_train_feats = extract_features(trained_global_extractor, X_train)         # shape (N, dense_proj_units)
# X_val_feats   = extract_features(trained_global_extractor, X_val_pad)      # your provided X_val_pad

# 2) Train XGBoost
xgb = XGBClassifier(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    use_label_encoder=False,
    eval_metric='logloss',
    tree_method='hist'  # change to 'gpu_hist' on GPU
)

# Use early stopping on validation features
xgb.fit(
    X_train_feats, y_train,
    
    eval_set=[(X_val_feats, y_val)],
    verbose=True
)
# Out:
# c:\Users\LENOVO\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [12:01:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	validation_0-logloss:0.65953
# [1]	validation_0-logloss:0.62916
# [2]	validation_0-logloss:0.60168
# [3]	validation_0-logloss:0.57658
# [4]	validation_0-logloss:0.55371
# [5]	validation_0-logloss:0.53275
# [6]	validation_0-logloss:0.51356
# [7]	validation_0-logloss:0.49589
# [8]	validation_0-logloss:0.47964
# [9]	validation_0-logloss:0.46463
# [10]	validation_0-logloss:0.45075
# [11]	validation_0-logloss:0.43794
# [12]	validation_0-logloss:0.42604
# [13]	validation_0-logloss:0.41500
# [14]	validation_0-logloss:0.40475
# [15]	validation_0-logloss:0.39523
# [16]	validation_0-logloss:0.38638
# [17]	validation_0-logloss:0.37816
# [18]	validation_0-logloss:0.37051
# [19]	validation_0-logloss:0.36335
# [20]	validation_0-logloss:0.35670
# [21]	validation_0-logloss:0.35048
# [22]	validation_0-logloss:0.34467
# [23]	validation_0-logloss:0.33924
# [24]	validation_0-logloss:0.33418
# [25]	validation_0-logloss:0.32946
# [26]	validation_0-logloss:0.32505
# [27]	validation_0-logloss:0.32091
# [28]	validation_0-logloss:0.31704
# [29]	validation_0-logloss:0.31343
# [30]	validation_0-logloss:0.31005
# [31]	validation_0-logloss:0.30688
# [32]	validation_0-logloss:0.30393
# [33]	validation_0-logloss:0.30116
# [34]	validation_0-logloss:0.29857
# [35]	validation_0-logloss:0.29614
# [36]	validation_0-logloss:0.29388
# [37]	validation_0-logloss:0.29176
# [38]	validation_0-logloss:0.28977
# [39]	validation_0-logloss:0.28788
# [40]	validation_0-logloss:0.28613
# [41]	validation_0-logloss:0.28451
# [42]	validation_0-logloss:0.28297
# [43]	validation_0-logloss:0.28154
# [44]	validation_0-logloss:0.28020
# [45]	validation_0-logloss:0.27895
# [46]	validation_0-logloss:0.27776
# [47]	validation_0-logloss:0.27667
# [48]	validation_0-logloss:0.27563
# [49]	validation_0-logloss:0.27467
# [50]	validation_0-logloss:0.27378
# [51]	validation_0-logloss:0.27293
# [52]	validation_0-logloss:0.27213
# [53]	validation_0-logloss:0.27140
# [54]	validation_0-logloss:0.27071
# [55]	validation_0-logloss:0.27005
# [56]	validation_0-logloss:0.26944
# [57]	validation_0-logloss:0.26886
# [58]	validation_0-logloss:0.26832
# [59]	validation_0-logloss:0.26783
# [60]	validation_0-logloss:0.26737
# [61]	validation_0-logloss:0.26693
# [62]	validation_0-logloss:0.26652
# [63]	validation_0-logloss:0.26613
# [64]	validation_0-logloss:0.26577
# [65]	validation_0-logloss:0.26542
# [66]	validation_0-logloss:0.26510
# [67]	validation_0-logloss:0.26483
# [68]	validation_0-logloss:0.26457
# [69]	validation_0-logloss:0.26432
# [70]	validation_0-logloss:0.26410
# [71]	validation_0-logloss:0.26387
# [72]	validation_0-logloss:0.26367
# [73]	validation_0-logloss:0.26348
# [74]	validation_0-logloss:0.26332
# [75]	validation_0-logloss:0.26316
# [76]	validation_0-logloss:0.26299
# [77]	validation_0-logloss:0.26285
# [78]	validation_0-logloss:0.26270
# [79]	validation_0-logloss:0.26258
# [80]	validation_0-logloss:0.26246
# [81]	validation_0-logloss:0.26234
# [82]	validation_0-logloss:0.26226
# [83]	validation_0-logloss:0.26217
# [84]	validation_0-logloss:0.26208
# [85]	validation_0-logloss:0.26200
# [86]	validation_0-logloss:0.26192
# [87]	validation_0-logloss:0.26185
# [88]	validation_0-logloss:0.26180
# [89]	validation_0-logloss:0.26174
# [90]	validation_0-logloss:0.26169
# [91]	validation_0-logloss:0.26164
# [92]	validation_0-logloss:0.26159
# [93]	validation_0-logloss:0.26155
# [94]	validation_0-logloss:0.26151
# [95]	validation_0-logloss:0.26147
# [96]	validation_0-logloss:0.26145
# [97]	validation_0-logloss:0.26141
# [98]	validation_0-logloss:0.26137
# [99]	validation_0-logloss:0.26135
# [100]	validation_0-logloss:0.26132
# [101]	validation_0-logloss:0.26128
# [102]	validation_0-logloss:0.26125
# [103]	validation_0-logloss:0.26123
# [104]	validation_0-logloss:0.26121
# [105]	validation_0-logloss:0.26118
# [106]	validation_0-logloss:0.26116
# [107]	validation_0-logloss:0.26117
# [108]	validation_0-logloss:0.26115
# [109]	validation_0-logloss:0.26113
# [110]	validation_0-logloss:0.26113
# [111]	validation_0-logloss:0.26111
# [112]	validation_0-logloss:0.26110
# [113]	validation_0-logloss:0.26110
# [114]	validation_0-logloss:0.26109
# [115]	validation_0-logloss:0.26109
# [116]	validation_0-logloss:0.26109
# [117]	validation_0-logloss:0.26110
# [118]	validation_0-logloss:0.26109
# [119]	validation_0-logloss:0.26107
# [120]	validation_0-logloss:0.26107
# [121]	validation_0-logloss:0.26107
# [122]	validation_0-logloss:0.26107
# [123]	validation_0-logloss:0.26106
# [124]	validation_0-logloss:0.26107
# [125]	validation_0-logloss:0.26107
# [126]	validation_0-logloss:0.26108
# [127]	validation_0-logloss:0.26108
# [128]	validation_0-logloss:0.26109
# [129]	validation_0-logloss:0.26108
# [130]	validation_0-logloss:0.26107
# [131]	validation_0-logloss:0.26106
# [132]	validation_0-logloss:0.26106
# [133]	validation_0-logloss:0.26106
# [134]	validation_0-logloss:0.26105
# [135]	validation_0-logloss:0.26105
# [136]	validation_0-logloss:0.26103
# [137]	validation_0-logloss:0.26101
# [138]	validation_0-logloss:0.26103
# [139]	validation_0-logloss:0.26103
# [140]	validation_0-logloss:0.26104
# [141]	validation_0-logloss:0.26105
# [142]	validation_0-logloss:0.26105
# [143]	validation_0-logloss:0.26104
# [144]	validation_0-logloss:0.26105
# [145]	validation_0-logloss:0.26106
# [146]	validation_0-logloss:0.26106
# [147]	validation_0-logloss:0.26105
# [148]	validation_0-logloss:0.26105
# [149]	validation_0-logloss:0.26104
# [150]	validation_0-logloss:0.26104
# [151]	validation_0-logloss:0.26104
# [152]	validation_0-logloss:0.26104
# [153]	validation_0-logloss:0.26104
# [154]	validation_0-logloss:0.26105
# [155]	validation_0-logloss:0.26105
# [156]	validation_0-logloss:0.26105
# [157]	validation_0-logloss:0.26106
# [158]	validation_0-logloss:0.26105
# [159]	validation_0-logloss:0.26105
# [160]	validation_0-logloss:0.26105
# [161]	validation_0-logloss:0.26105
# [162]	validation_0-logloss:0.26105
# [163]	validation_0-logloss:0.26103
# [164]	validation_0-logloss:0.26103
# [165]	validation_0-logloss:0.26104
# [166]	validation_0-logloss:0.26104
# [167]	validation_0-logloss:0.26103
# [168]	validation_0-logloss:0.26104
# [169]	validation_0-logloss:0.26103
# [170]	validation_0-logloss:0.26103
# [171]	validation_0-logloss:0.26103
# [172]	validation_0-logloss:0.26103
# [173]	validation_0-logloss:0.26101
# [174]	validation_0-logloss:0.26103
# [175]	validation_0-logloss:0.26103
# [176]	validation_0-logloss:0.26103
# [177]	validation_0-logloss:0.26103
# [178]	validation_0-logloss:0.26101
# [179]	validation_0-logloss:0.26101
# [180]	validation_0-logloss:0.26101
# [181]	validation_0-logloss:0.26100
# [182]	validation_0-logloss:0.26101
# [183]	validation_0-logloss:0.26102
# [184]	validation_0-logloss:0.26103
# [185]	validation_0-logloss:0.26103
# [186]	validation_0-logloss:0.26103
# [187]	validation_0-logloss:0.26104
# [188]	validation_0-logloss:0.26104
# [189]	validation_0-logloss:0.26102
# [190]	validation_0-logloss:0.26101
# [191]	validation_0-logloss:0.26102
# [192]	validation_0-logloss:0.26103
# [193]	validation_0-logloss:0.26103
# [194]	validation_0-logloss:0.26102
# [195]	validation_0-logloss:0.26102
# [196]	validation_0-logloss:0.26102
# [197]	validation_0-logloss:0.26101
# [198]	validation_0-logloss:0.26101
# [199]	validation_0-logloss:0.26101
# [200]	validation_0-logloss:0.26101
# [201]	validation_0-logloss:0.26101
# [202]	validation_0-logloss:0.26102
# [203]	validation_0-logloss:0.26101
# [204]	validation_0-logloss:0.26102
# [205]	validation_0-logloss:0.26102
# [206]	validation_0-logloss:0.26103
# [207]	validation_0-logloss:0.26103
# [208]	validation_0-logloss:0.26102
# [209]	validation_0-logloss:0.26103
# [210]	validation_0-logloss:0.26102
# [211]	validation_0-logloss:0.26101
# [212]	validation_0-logloss:0.26101
# [213]	validation_0-logloss:0.26101
# [214]	validation_0-logloss:0.26100
# [215]	validation_0-logloss:0.26099
# [216]	validation_0-logloss:0.26098
# [217]	validation_0-logloss:0.26098
# [218]	validation_0-logloss:0.26098
# [219]	validation_0-logloss:0.26098
# [220]	validation_0-logloss:0.26099
# [221]	validation_0-logloss:0.26099
# [222]	validation_0-logloss:0.26099
# [223]	validation_0-logloss:0.26099
# [224]	validation_0-logloss:0.26097
# [225]	validation_0-logloss:0.26098
# [226]	validation_0-logloss:0.26096
# [227]	validation_0-logloss:0.26096
# [228]	validation_0-logloss:0.26096
# [229]	validation_0-logloss:0.26095
# [230]	validation_0-logloss:0.26097
# [231]	validation_0-logloss:0.26098
# [232]	validation_0-logloss:0.26096
# [233]	validation_0-logloss:0.26096
# [234]	validation_0-logloss:0.26095
# [235]	validation_0-logloss:0.26094
# [236]	validation_0-logloss:0.26095
# [237]	validation_0-logloss:0.26096
# [238]	validation_0-logloss:0.26094
# [239]	validation_0-logloss:0.26095
# [240]	validation_0-logloss:0.26095
# [241]	validation_0-logloss:0.26096
# [242]	validation_0-logloss:0.26098
# [243]	validation_0-logloss:0.26096
# [244]	validation_0-logloss:0.26096
# [245]	validation_0-logloss:0.26096
# [246]	validation_0-logloss:0.26097
# [247]	validation_0-logloss:0.26097
# [248]	validation_0-logloss:0.26098
# [249]	validation_0-logloss:0.26097
# [250]	validation_0-logloss:0.26097
# [251]	validation_0-logloss:0.26098
# [252]	validation_0-logloss:0.26097
# [253]	validation_0-logloss:0.26097
# [254]	validation_0-logloss:0.26097
# [255]	validation_0-logloss:0.26096
# [256]	validation_0-logloss:0.26097
# [257]	validation_0-logloss:0.26097
# [258]	validation_0-logloss:0.26097
# [259]	validation_0-logloss:0.26098
# [260]	validation_0-logloss:0.26097
# [261]	validation_0-logloss:0.26098
# [262]	validation_0-logloss:0.26097
# [263]	validation_0-logloss:0.26097
# [264]	validation_0-logloss:0.26097
# [265]	validation_0-logloss:0.26099
# [266]	validation_0-logloss:0.26098
# [267]	validation_0-logloss:0.26098
# [268]	validation_0-logloss:0.26097
# [269]	validation_0-logloss:0.26096
# [270]	validation_0-logloss:0.26095
# [271]	validation_0-logloss:0.26095
# [272]	validation_0-logloss:0.26095
# [273]	validation_0-logloss:0.26096
# [274]	validation_0-logloss:0.26095
# [275]	validation_0-logloss:0.26095
# [276]	validation_0-logloss:0.26094
# [277]	validation_0-logloss:0.26094
# [278]	validation_0-logloss:0.26092
# [279]	validation_0-logloss:0.26092
# [280]	validation_0-logloss:0.26091
# [281]	validation_0-logloss:0.26092
# [282]	validation_0-logloss:0.26093
# [283]	validation_0-logloss:0.26092
# [284]	validation_0-logloss:0.26092
# [285]	validation_0-logloss:0.26092
# [286]	validation_0-logloss:0.26092
# [287]	validation_0-logloss:0.26093
# [288]	validation_0-logloss:0.26093
# [289]	validation_0-logloss:0.26092
# [290]	validation_0-logloss:0.26092
# [291]	validation_0-logloss:0.26093
# [292]	validation_0-logloss:0.26093
# [293]	validation_0-logloss:0.26092
# [294]	validation_0-logloss:0.26091
# [295]	validation_0-logloss:0.26090
# [296]	validation_0-logloss:0.26089
# [297]	validation_0-logloss:0.26090
# [298]	validation_0-logloss:0.26091
# [299]	validation_0-logloss:0.26091
# [300]	validation_0-logloss:0.26090
# [301]	validation_0-logloss:0.26089
# [302]	validation_0-logloss:0.26089
# [303]	validation_0-logloss:0.26089
# [304]	validation_0-logloss:0.26089
# [305]	validation_0-logloss:0.26089
# [306]	validation_0-logloss:0.26090
# [307]	validation_0-logloss:0.26090
# [308]	validation_0-logloss:0.26091
# [309]	validation_0-logloss:0.26090
# [310]	validation_0-logloss:0.26092
# [311]	validation_0-logloss:0.26092
# [312]	validation_0-logloss:0.26093
# [313]	validation_0-logloss:0.26094
# [314]	validation_0-logloss:0.26093
# [315]	validation_0-logloss:0.26094
# [316]	validation_0-logloss:0.26094
# [317]	validation_0-logloss:0.26095
# [318]	validation_0-logloss:0.26093
# [319]	validation_0-logloss:0.26093
# [320]	validation_0-logloss:0.26092
# [321]	validation_0-logloss:0.26093
# [322]	validation_0-logloss:0.26092
# [323]	validation_0-logloss:0.26092
# [324]	validation_0-logloss:0.26092
# [325]	validation_0-logloss:0.26093
# [326]	validation_0-logloss:0.26091
# [327]	validation_0-logloss:0.26092
# [328]	validation_0-logloss:0.26092
# [329]	validation_0-logloss:0.26092
# [330]	validation_0-logloss:0.26091
# [331]	validation_0-logloss:0.26091
# [332]	validation_0-logloss:0.26092
# [333]	validation_0-logloss:0.26093
# [334]	validation_0-logloss:0.26093
# [335]	validation_0-logloss:0.26093
# [336]	validation_0-logloss:0.26092
# [337]	validation_0-logloss:0.26093
# [338]	validation_0-logloss:0.26092
# [339]	validation_0-logloss:0.26094
# [340]	validation_0-logloss:0.26095
# [341]	validation_0-logloss:0.26096
# [342]	validation_0-logloss:0.26095
# [343]	validation_0-logloss:0.26094
# [344]	validation_0-logloss:0.26094
# [345]	validation_0-logloss:0.26094
# [346]	validation_0-logloss:0.26095
# [347]	validation_0-logloss:0.26095
# [348]	validation_0-logloss:0.26095
# [349]	validation_0-logloss:0.26096
# [350]	validation_0-logloss:0.26097
# [351]	validation_0-logloss:0.26097
# [352]	validation_0-logloss:0.26098
# [353]	validation_0-logloss:0.26097
# [354]	validation_0-logloss:0.26097
# [355]	validation_0-logloss:0.26098
# [356]	validation_0-logloss:0.26098
# [357]	validation_0-logloss:0.26097
# [358]	validation_0-logloss:0.26097
# [359]	validation_0-logloss:0.26097
# [360]	validation_0-logloss:0.26098
# [361]	validation_0-logloss:0.26098
# [362]	validation_0-logloss:0.26097
# [363]	validation_0-logloss:0.26097
# [364]	validation_0-logloss:0.26099
# [365]	validation_0-logloss:0.26099
# [366]	validation_0-logloss:0.26099
# [367]	validation_0-logloss:0.26099
# [368]	validation_0-logloss:0.26099
# [369]	validation_0-logloss:0.26100
# [370]	validation_0-logloss:0.26100
# [371]	validation_0-logloss:0.26098
# [372]	validation_0-logloss:0.26100
# [373]	validation_0-logloss:0.26101
# [374]	validation_0-logloss:0.26101
# [375]	validation_0-logloss:0.26102
# [376]	validation_0-logloss:0.26102
# [377]	validation_0-logloss:0.26101
# [378]	validation_0-logloss:0.26102
# [379]	validation_0-logloss:0.26102
# [380]	validation_0-logloss:0.26102
# [381]	validation_0-logloss:0.26102
# [382]	validation_0-logloss:0.26102
# [383]	validation_0-logloss:0.26104
# [384]	validation_0-logloss:0.26104
# [385]	validation_0-logloss:0.26104
# [386]	validation_0-logloss:0.26104
# [387]	validation_0-logloss:0.26102
# [388]	validation_0-logloss:0.26102
# [389]	validation_0-logloss:0.26103
# [390]	validation_0-logloss:0.26102
# [391]	validation_0-logloss:0.26102
# [392]	validation_0-logloss:0.26103
# [393]	validation_0-logloss:0.26103
# [394]	validation_0-logloss:0.26103
# [395]	validation_0-logloss:0.26102
# [396]	validation_0-logloss:0.26103
# [397]	validation_0-logloss:0.26102
# [398]	validation_0-logloss:0.26102
# [399]	validation_0-logloss:0.26103
# [400]	validation_0-logloss:0.26103
# [401]	validation_0-logloss:0.26104
# [402]	validation_0-logloss:0.26105
# [403]	validation_0-logloss:0.26104
# [404]	validation_0-logloss:0.26105
# [405]	validation_0-logloss:0.26105
# [406]	validation_0-logloss:0.26106
# [407]	validation_0-logloss:0.26105
# [408]	validation_0-logloss:0.26106
# [409]	validation_0-logloss:0.26105
# [410]	validation_0-logloss:0.26105
# [411]	validation_0-logloss:0.26104
# [412]	validation_0-logloss:0.26106
# [413]	validation_0-logloss:0.26106
# [414]	validation_0-logloss:0.26107
# [415]	validation_0-logloss:0.26108
# [416]	validation_0-logloss:0.26108
# [417]	validation_0-logloss:0.26108
# [418]	validation_0-logloss:0.26108
# [419]	validation_0-logloss:0.26108
# [420]	validation_0-logloss:0.26107
# [421]	validation_0-logloss:0.26107
# [422]	validation_0-logloss:0.26107
# [423]	validation_0-logloss:0.26108
# [424]	validation_0-logloss:0.26107
# [425]	validation_0-logloss:0.26107
# [426]	validation_0-logloss:0.26108
# [427]	validation_0-logloss:0.26108
# [428]	validation_0-logloss:0.26109
# [429]	validation_0-logloss:0.26109
# [430]	validation_0-logloss:0.26109
# [431]	validation_0-logloss:0.26109
# [432]	validation_0-logloss:0.26109
# [433]	validation_0-logloss:0.26110
# [434]	validation_0-logloss:0.26110
# [435]	validation_0-logloss:0.26111
# [436]	validation_0-logloss:0.26111
# [437]	validation_0-logloss:0.26113
# [438]	validation_0-logloss:0.26113
# [439]	validation_0-logloss:0.26113
# [440]	validation_0-logloss:0.26114
# [441]	validation_0-logloss:0.26114
# [442]	validation_0-logloss:0.26115
# [443]	validation_0-logloss:0.26116
# [444]	validation_0-logloss:0.26117
# [445]	validation_0-logloss:0.26117
# [446]	validation_0-logloss:0.26118
# [447]	validation_0-logloss:0.26119
# [448]	validation_0-logloss:0.26119
# [449]	validation_0-logloss:0.26121
# [450]	validation_0-logloss:0.26121
# [451]	validation_0-logloss:0.26121
# [452]	validation_0-logloss:0.26121
# [453]	validation_0-logloss:0.26123
# [454]	validation_0-logloss:0.26123
# [455]	validation_0-logloss:0.26123
# [456]	validation_0-logloss:0.26121
# [457]	validation_0-logloss:0.26121
# [458]	validation_0-logloss:0.26120
# [459]	validation_0-logloss:0.26120
# [460]	validation_0-logloss:0.26122
# [461]	validation_0-logloss:0.26122
# [462]	validation_0-logloss:0.26122
# [463]	validation_0-logloss:0.26122
# [464]	validation_0-logloss:0.26122
# [465]	validation_0-logloss:0.26123
# [466]	validation_0-logloss:0.26123
# [467]	validation_0-logloss:0.26124
# [468]	validation_0-logloss:0.26125
# [469]	validation_0-logloss:0.26126
# [470]	validation_0-logloss:0.26126
# [471]	validation_0-logloss:0.26127
# [472]	validation_0-logloss:0.26130
# [473]	validation_0-logloss:0.26129
# [474]	validation_0-logloss:0.26129
# [475]	validation_0-logloss:0.26129
# [476]	validation_0-logloss:0.26129
# [477]	validation_0-logloss:0.26129
# [478]	validation_0-logloss:0.26130
# [479]	validation_0-logloss:0.26131
# [480]	validation_0-logloss:0.26131
# [481]	validation_0-logloss:0.26131
# [482]	validation_0-logloss:0.26130
# [483]	validation_0-logloss:0.26130
# [484]	validation_0-logloss:0.26130
# [485]	validation_0-logloss:0.26130
# [486]	validation_0-logloss:0.26131
# [487]	validation_0-logloss:0.26131
# [488]	validation_0-logloss:0.26131
# [489]	validation_0-logloss:0.26131
# [490]	validation_0-logloss:0.26131
# [491]	validation_0-logloss:0.26133
# [492]	validation_0-logloss:0.26131
# [493]	validation_0-logloss:0.26131
# [494]	validation_0-logloss:0.26131
# [495]	validation_0-logloss:0.26132
# [496]	validation_0-logloss:0.26131
# [497]	validation_0-logloss:0.26132
# [498]	validation_0-logloss:0.26134
# [499]	validation_0-logloss:0.26134
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from sklearn.metrics import classification_report, roc_auc_score , accuracy_score

# %%
y_val_pred_proba = xgb.predict_proba(X_val_feats)[:,1]
y_val_pred = (y_val_pred_proba >= 0.5).astype(int)

print(classification_report(y_val, y_val_pred))
print("AUC:", roc_auc_score(y_val, y_val_pred_proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88     35358
#            1       0.85      0.93      0.89     35524
#
#     accuracy                           0.89     70882
#    macro avg       0.89      0.89      0.89     70882
# weighted avg       0.89      0.89      0.89     70882
#
# AUC: 0.9558220754737495

# %%
X_test_feats   = extract_features(trained_global_extractor, X_test_pad)
# Out:
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 46s 334ms/step

# %%
y_test_pred_proba = xgb.predict_proba(X_test_feats)[:,1]
y_test_pred = (y_test_pred_proba >= 0.5).astype(int)

print(classification_report(y_test, y_test_pred))
print("AUC:", roc_auc_score(y_test, y_test_pred_proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88     35239
#            1       0.85      0.93      0.89     35643
#
#     accuracy                           0.89     70882
#    macro avg       0.89      0.89      0.89     70882
# weighted avg       0.89      0.89      0.89     70882
#
# AUC: 0.9554982545126018

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test, y_test_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(accuracy_score(y_test, y_test_pred))
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# WITH ATTENTION LAYER

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, clone_model
from tensorflow.keras.layers import (Input, Embedding, Conv1D, BatchNormalization,
                                     LeakyReLU, MaxPooling1D, Concatenate,
                                     Bidirectional, LSTM, Dense, Dropout, Attention)
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.layers import GlobalAveragePooling1D

def build_attention_model(vocab_size, maxlen,
                          embedding_dim=64,
                          conv_filters=128,
                          conv_kernel_sizes=[3,5,7],
                          pool_size=2,
                          bilstm_units=128,
                          dense_proj_units=128,
                          dropout_rate=0.3):

    inp = Input(shape=(maxlen,), dtype='int32', name='input_ids')

    # Embedding layer
    x = Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  input_length=maxlen,
                  mask_zero=False,
                  name='embedding')(inp)

    # Parallel Conv1D layers
    convs = []
    for k in conv_kernel_sizes:
        c = Conv1D(filters=conv_filters, kernel_size=k, padding='same')(x)
        c = BatchNormalization()(c)
        c = LeakyReLU(alpha=0.1)(c)
        c = MaxPooling1D(pool_size=pool_size)(c)
        convs.append(c)

    x = Concatenate(axis=-1)(convs)

    # Extra convolution for richer features
    x = Conv1D(filters=conv_filters, kernel_size=3, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)

    # BiLSTM contextual layer
    x = Bidirectional(LSTM(bilstm_units, return_sequences=True))(x)

    # Attention layer (self-attention)
    attn_out = Attention()([x, x])
    attn_vec = GlobalAveragePooling1D()(attn_out)  # safer than tf.reduce_mean

    # Dense + dropout
    x = Dense(dense_proj_units, activation='gelu')(attn_vec)
    x = Dropout(dropout_rate)(x)

    # Final sigmoid output
    out = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=inp, outputs=out, name='cnn_bilstm_attention')
    return model

# %%
def compile_local_model_from_global(global_model, learning_rate=0.001):
    """Clone and compile the global model for each client."""
    model = clone_model(global_model)
    model.set_weights(global_model.get_weights())
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model


def average_weights(client_weights):
    """Average weights from all clients."""
    avg_weights = []
    for weights in zip(*client_weights):
        avg_weights.append(np.mean(weights, axis=0))
    return avg_weights


def federated_train(global_model, X_train, y_train,
                    X_val, y_val,
                    num_clients=5,
                    rounds=3,
                    local_epochs=1,
                    batch_size=256,
                    learning_rate=0.001,
                    non_iid=False):
    """Simulate federated averaging across clients."""

    n_samples = len(X_train)
    indices = np.arange(n_samples)
    np.random.shuffle(indices)

    client_splits = np.array_split(indices, num_clients)

    for r in range(rounds):
        print(f"\n🌍 Federated Round {r+1}/{rounds}")
        client_weights = []

        for i, idxs in enumerate(client_splits):
            print(f"  🔹 Client {i+1}: {len(idxs)} samples")

            X_c, y_c = X_train[idxs], y_train[idxs]

            local_model = compile_local_model_from_global(global_model, learning_rate)
            local_model.fit(X_c, y_c,
                            epochs=local_epochs,
                            batch_size=batch_size,
                            verbose=1)
            client_weights.append(local_model.get_weights())

        # Federated averaging
        new_weights = average_weights(client_weights)
        global_model.set_weights(new_weights)

        # Validation performance
        loss, acc = global_model.evaluate(X_val, y_val, verbose=1)
        print(f"  ✅ Global model accuracy after round {r+1}: {acc:.4f}")

    return global_model

# %%
# Example params (replace with your actual data vars)
vocab_size = 44
maxlen = 182
embedding_dim = 64
conv_filters = 128
bilstm_units = 128
dense_proj_units = 128
batch_size = 512
learning_rate = 0.001

# Build model
global_model = build_attention_model(vocab_size, maxlen,
                                     embedding_dim,
                                     conv_filters,
                                     bilstm_units=bilstm_units,
                                     dense_proj_units=dense_proj_units)

global_model.compile(optimizer=Adam(learning_rate=learning_rate),
                     loss='binary_crossentropy',
                     metrics=['accuracy'])

# Run federated training (simulation)
trained_global = federated_train(global_model,
                                 X_train_pad, y_train,
                                 X_val=X_val_pad, y_val=y_val,
                                 num_clients=4,
                                 rounds=3,
                                 local_epochs=1,
                                 batch_size=batch_size,
                                 learning_rate=learning_rate)
# Out:
# 🌍 Federated Round 1/3
#   🔹 Client 1: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 373s 1s/step - accuracy: 0.8319 - loss: 0.3764
#   🔹 Client 2: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 358s 1s/step - accuracy: 0.8378 - loss: 0.3674
#   🔹 Client 3: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.8307 - loss: 0.3761
#   🔹 Client 4: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 335s 1s/step - accuracy: 0.8306 - loss: 0.3783
#   ✅ Global model accuracy after round 1: 0.4988
#
# 🌍 Federated Round 2/3
#   🔹 Client 1: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 349s 1s/step - accuracy: 0.8699 - loss: 0.3109
#   🔹 Client 2: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 354s 1s/step - accuracy: 0.8717 - loss: 0.3093
#   🔹 Client 3: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 411s 2s/step - accuracy: 0.8692 - loss: 0.3142
#   🔹 Client 4: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 394s 1s/step - accuracy: 0.8695 - loss: 0.3139
#   ✅ Global model accuracy after round 2: 0.8057
#
# 🌍 Federated Round 3/3
#   🔹 Client 1: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 430s 2s/step - accuracy: 0.8870 - loss: 0.2741
#   🔹 Client 2: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 404s 2s/step - accuracy: 0.8863 - loss: 0.2739
#   🔹 Client 3: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 407s 2s/step - accuracy: 0.8858 - loss: 0.2761
#   🔹 Client 4: 131341 samples
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 439s 2s/step - accuracy: 0.8863 - loss: 0.2768
#   ✅ Global model accuracy after round 3: 0.7929

# %%
loss, acc = trained_global.evaluate(X_val_pad, y_val, verbose=1)
print(f"\nFinal Validation Accuracy: {acc:.4f}")
# Out:
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 196s 88ms/step - accuracy: 0.7929 - loss: 0.4053
#
# Final Validation Accuracy: 0.7929

# %% [markdown]
# Manually adding features

# %%
pip install pydot
# Out:
# Collecting pydotNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing>=3.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydot) (3.2.0)
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Installing collected packages: pydot
# Successfully installed pydot-4.0.1

# %%
from tensorflow.keras.utils import plot_model

plot_model(
    trained_global,
    to_file='model_structure.png',
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    dpi=100
)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.
