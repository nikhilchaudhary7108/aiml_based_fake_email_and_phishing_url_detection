# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ndarvind/phiusiil-phishing-url-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'phiusiil-phishing-url-dataset' dataset.
# Path to dataset files: /kaggle/input/phiusiil-phishing-url-dataset

# %%
import os

dataset_path = "/kaggle/input/phiusiil-phishing-url-dataset"

# %%
files_in_dataset = os.listdir(dataset_path)

# %%
for file in files_in_dataset:
  print(file)
  print('*'*10)
# Out:
# PhiUSIIL_Phishing_URL_Dataset.csv
# **********

# %%
df = pd.read_csv(os.path.join(dataset_path,"PhiUSIIL_Phishing_URL_Dataset.csv"))

# %%
df.shape
# Out:
# (235795, 55)

# %%
df.head()
# Out:
#                                   URL  URLLength                      Domain  \
# 0    https://www.southbankmosaics.com         31    www.southbankmosaics.com
# 1            https://www.uni-mainz.de         23            www.uni-mainz.de
# 2      https://www.voicefmradio.co.uk         29      www.voicefmradio.co.uk
# 3         https://www.sfnmjournal.com         26         www.sfnmjournal.com
# 4  https://www.rewildingargentina.org         33  www.rewildingargentina.org
#
#    DomainLength  IsDomainIP  TLD  URLSimilarityIndex  CharContinuationRate  \
# 0            24           0  com               100.0              1.000000
# 1            16           0   de               100.0              0.666667
# 2            22           0   uk               100.0              0.866667
# 3            19           0  com               100.0              1.000000
# 4            26           0  org               100.0              1.000000
#
#    TLDLegitimateProb  URLCharProb  ...  Pay  Crypto  HasCopyrightInfo  \
# 0           0.522907     0.061933  ...    0       0                 1
# 1           0.032650     0.050207  ...    0       0                 1
# 2           0.028555     0.064129  ...    0       0                 1
# 3           0.522907     0.057606  ...    1       1                 1
# 4           0.079963     0.059441  ...    1       0                 1
#
#    NoOfImage  NoOfCSS  NoOfJS  NoOfSelfRef  NoOfEmptyRef  NoOfExternalRef  \
# 0         34       20      28          119             0              124
# 1         50        9       8           39             0              217
# 2         10        2       7           42             2                5
# 3          3       27      15           22             1               31
# 4        244       15      34           72             1               85
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#
# [5 rows x 55 columns]

# %% [markdown]
# # COLUMN WISE INFORMATION

# %%
import pandas as pd

def dataframe_summary(df):
    summary = pd.DataFrame({
        "DataType": df.dtypes,
        "Non-Null Count": df.count(),
        "Missing Values": df.isnull().sum(),
        "Unique Values": df.nunique(),
        "First Value": df.iloc[0],
        "Sample Values": df.apply(lambda x: x.unique()[:5])  # first 5 unique values
    })
    return summary

# Example usage
summary_table = dataframe_summary(df)
print(summary_table)
# Out:
#                            DataType  Non-Null Count  Missing Values  \
# URL                          object          235795               0
# URLLength                     int64          235795               0
# Domain                       object          235795               0
# DomainLength                  int64          235795               0
# IsDomainIP                    int64          235795               0
# TLD                          object          235795               0
# URLSimilarityIndex          float64          235795               0
# CharContinuationRate        float64          235795               0
# TLDLegitimateProb           float64          235795               0
# URLCharProb                 float64          235795               0
# TLDLength                     int64          235795               0
# NoOfSubDomain                 int64          235795               0
# HasObfuscation                int64          235795               0
# NoOfObfuscatedChar            int64          235795               0
# ObfuscationRatio            float64          235795               0
# NoOfLettersInURL              int64          235795               0
# LetterRatioInURL            float64          235795               0
# NoOfDegitsInURL               int64          235795               0
# DegitRatioInURL             float64          235795               0
# NoOfEqualsInURL               int64          235795               0
# NoOfQMarkInURL                int64          235795               0
# NoOfAmpersandInURL            int64          235795               0
# NoOfOtherSpecialCharsInURL    int64          235795               0
# SpacialCharRatioInURL       float64          235795               0
# IsHTTPS                       int64          235795               0
# LineOfCode                    int64          235795               0
# LargestLineLength             int64          235795               0
# HasTitle                      int64          235795               0
# Title                        object          235795               0
# DomainTitleMatchScore       float64          235795               0
# URLTitleMatchScore          float64          235795               0
# HasFavicon                    int64          235795               0
# Robots                        int64          235795               0
# IsResponsive                  int64          235795               0
# NoOfURLRedirect               int64          235795               0
# NoOfSelfRedirect              int64          235795               0
# HasDescription                int64          235795               0
# NoOfPopup                     int64          235795               0
# NoOfiFrame                    int64          235795               0
# HasExternalFormSubmit         int64          235795               0
# HasSocialNet                  int64          235795               0
# HasSubmitButton               int64          235795               0
# HasHiddenFields               int64          235795               0
# HasPasswordField              int64          235795               0
# Bank                          int64          235795               0
# Pay                           int64          235795               0
# Crypto                        int64          235795               0
# HasCopyrightInfo              int64          235795               0
# NoOfImage                     int64          235795               0
# NoOfCSS                       int64          235795               0
# NoOfJS                        int64          235795               0
# NoOfSelfRef                   int64          235795               0
# NoOfEmptyRef                  int64          235795               0
# NoOfExternalRef               int64          235795               0
# label                         int64          235795               0
#
#                             Unique Values  \
# URL                                235370
# URLLength                             482
# Domain                             220086
# DomainLength                          101
# IsDomainIP                              2
# TLD                                   695
# URLSimilarityIndex                  36360
# CharContinuationRate                  898
# TLDLegitimateProb                     465
# URLCharProb                        227421
# TLDLength                              12
# NoOfSubDomain                          10
# HasObfuscation                          2
# NoOfObfuscatedChar                     20
# ObfuscationRatio                      146
# NoOfLettersInURL                      421
# LetterRatioInURL                      709
# NoOfDegitsInURL                       182
# DegitRatioInURL                       575
# NoOfEqualsInURL                        25
# NoOfQMarkInURL                          5
# NoOfAmpersandInURL                     31
# NoOfOtherSpecialCharsInURL             74
# SpacialCharRatioInURL                 240
# IsHTTPS                                 2
# LineOfCode                          10738
# LargestLineLength                   26181
# HasTitle                                2
# Title                              197874
# DomainTitleMatchScore                 152
# URLTitleMatchScore                    497
# HasFavicon                              2
# Robots                                  2
# IsResponsive                            2
# NoOfURLRedirect                         2
# NoOfSelfRedirect                        2
# HasDescription                          2
# NoOfPopup                             115
# NoOfiFrame                            119
# HasExternalFormSubmit                   2
# HasSocialNet                            2
# HasSubmitButton                         2
# HasHiddenFields                         2
# HasPasswordField                        2
# Bank                                    2
# Pay                                     2
# Crypto                                  2
# HasCopyrightInfo                        2
# NoOfImage                             992
# NoOfCSS                               209
# NoOfJS                                253
# NoOfSelfRef                          1374
# NoOfEmptyRef                          296
# NoOfExternalRef                      1191
# label                                   2
#
#                                                                   First Value  \
# URL                                          https://www.southbankmosaics.com
# URLLength                                                                  31
# Domain                                               www.southbankmosaics.com
# DomainLength                                                               24
# IsDomainIP                                                                  0
# TLD                                                                       com
# URLSimilarityIndex                                                      100.0
# CharContinuationRate                                                      1.0
# TLDLegitimateProb                                                    0.522907
# URLCharProb                                                          0.061933
# TLDLength                                                                   3
# NoOfSubDomain                                                               1
# HasObfuscation                                                              0
# NoOfObfuscatedChar                                                          0
# ObfuscationRatio                                                          0.0
# NoOfLettersInURL                                                           18
# LetterRatioInURL                                                        0.581
# NoOfDegitsInURL                                                             0
# DegitRatioInURL                                                           0.0
# NoOfEqualsInURL                                                             0
# NoOfQMarkInURL                                                              0
# NoOfAmpersandInURL                                                          0
# NoOfOtherSpecialCharsInURL                                                  1
# SpacialCharRatioInURL                                                   0.032
# IsHTTPS                                                                     1
# LineOfCode                                                                558
# LargestLineLength                                                        9381
# HasTitle                                                                    1
# Title                       à¸‚à¹ˆà¸²à¸§à¸ªà¸” à¸‚à¹ˆà¸²à¸§à¸§à¸±à¸™à¸™à¸µ...
# DomainTitleMatchScore                                                     0.0
# URLTitleMatchScore                                                        0.0
# HasFavicon                                                                  0
# Robots                                                                      1
# IsResponsive                                                                1
# NoOfURLRedirect                                                             0
# NoOfSelfRedirect                                                            0
# HasDescription                                                              0
# NoOfPopup                                                                   0
# NoOfiFrame                                                                  1
# HasExternalFormSubmit                                                       0
# HasSocialNet                                                                0
# HasSubmitButton                                                             1
# HasHiddenFields                                                             1
# HasPasswordField                                                            0
# Bank                                                                        1
# Pay                                                                         0
# Crypto                                                                      0
# HasCopyrightInfo                                                            1
# NoOfImage                                                                  34
# NoOfCSS                                                                    20
# NoOfJS                                                                     28
# NoOfSelfRef                                                               119
# NoOfEmptyRef                                                                0
# NoOfExternalRef                                                           124
# label                                                                       1
#
#                                                                 Sample Values
# URL                         [https://www.southbankmosaics.com, https://www...
# URLLength                                                [31, 23, 29, 26, 33]
# Domain                      [www.southbankmosaics.com, www.uni-mainz.de, w...
# DomainLength                                             [24, 16, 22, 19, 26]
# IsDomainIP                                                             [0, 1]
# TLD                                                    [com, de, uk, org, in]
# URLSimilarityIndex          [100.0, 82.6446281, 55.28492647, 56.55114117, ...
# CharContinuationRate        [1.0, 0.666666667, 0.866666667, 0.625, 0.92307...
# TLDLegitimateProb           [0.5229071, 0.0326503, 0.028555, 0.0799628, 0....
# URLCharProb                 [0.061933179, 0.050207214, 0.06412872, 0.05760...
# TLDLength                                                     [3, 2, 4, 5, 6]
# NoOfSubDomain                                                 [1, 2, 3, 0, 5]
# HasObfuscation                                                         [0, 1]
# NoOfObfuscatedChar                                          [0, 9, 3, 15, 18]
# ObfuscationRatio                            [0.0, 0.098, 0.024, 0.016, 0.053]
# NoOfLettersInURL                                          [18, 9, 15, 13, 20]
# LetterRatioInURL                            [0.581, 0.391, 0.517, 0.5, 0.606]
# NoOfDegitsInURL                                              [0, 2, 7, 4, 12]
# DegitRatioInURL                               [0.0, 0.1, 0.269, 0.062, 0.154]
# NoOfEqualsInURL                                               [0, 1, 2, 3, 5]
# NoOfQMarkInURL                                                [0, 1, 3, 2, 4]
# NoOfAmpersandInURL                                           [0, 3, 1, 2, 15]
# NoOfOtherSpecialCharsInURL                                   [1, 2, 3, 5, 11]
# SpacialCharRatioInURL                      [0.032, 0.087, 0.069, 0.038, 0.03]
# IsHTTPS                                                                [1, 0]
# LineOfCode                                        [558, 618, 467, 6356, 6089]
# LargestLineLength                              [9381, 682, 26824, 28404, 737]
# HasTitle                                                               [1, 0]
# Title                       [à¸‚à¹ˆà¸²à¸§à¸ªà¸” à¸‚à¹ˆà¸²à¸§à¸§à¸±à¸™à¸™à¸...
# DomainTitleMatchScore            [0.0, 55.55555556, 46.66666667, 100.0, 50.0]
# URLTitleMatchScore               [0.0, 55.55555556, 46.66666667, 100.0, 50.0]
# HasFavicon                                                             [0, 1]
# Robots                                                                 [1, 0]
# IsResponsive                                                           [1, 0]
# NoOfURLRedirect                                                        [0, 1]
# NoOfSelfRedirect                                                       [0, 1]
# HasDescription                                                         [0, 1]
# NoOfPopup                                                    [0, 1, 2, 12, 3]
# NoOfiFrame                                                   [1, 0, 12, 2, 4]
# HasExternalFormSubmit                                                  [0, 1]
# HasSocialNet                                                           [0, 1]
# HasSubmitButton                                                        [1, 0]
# HasHiddenFields                                                        [1, 0]
# HasPasswordField                                                       [0, 1]
# Bank                                                                   [1, 0]
# Pay                                                                    [0, 1]
# Crypto                                                                 [0, 1]
# HasCopyrightInfo                                                       [1, 0]
# NoOfImage                                                [34, 50, 10, 3, 244]
# NoOfCSS                                                    [20, 9, 2, 27, 15]
# NoOfJS                                                     [28, 8, 7, 15, 34]
# NoOfSelfRef                                             [119, 39, 42, 22, 72]
# NoOfEmptyRef                                                 [0, 2, 1, 6, 12]
# NoOfExternalRef                                         [124, 217, 5, 31, 85]
# label                                                                  [1, 0]

# %%
df['label'].value_counts()
# Out:
# label
# 1    134850
# 0    100945
# Name: count, dtype: int64

# %% [markdown]
# # Class Labels :
# Label 1 corresponds to a legitimate URL, label 0 to a phishing URL

# %% [markdown]
# # Data Cleaning

# %%
df['URL'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['URL'].duplicated().sum()
# Out:
# np.int64(425)

# %%
df = df.drop_duplicates(subset=['URL'])

# %% [markdown]
# 1. Before dropping the duplicates the shape fo dataset was : (235795, 55)
# 2. After dropping the duplicates ------------------------- : (235370, 55)

# %%
df.shape
# Out:
# (235370, 55)

# %% [markdown]
# Although the data is little imbalance , we may do oversampling . But as we are going for deep learning , we may just adjust class weights.

# %%
df.dtypes
# Out:
# URL                            object
# URLLength                       int64
# Domain                         object
# DomainLength                    int64
# IsDomainIP                      int64
# TLD                            object
# URLSimilarityIndex            float64
# CharContinuationRate          float64
# TLDLegitimateProb             float64
# URLCharProb                   float64
# TLDLength                       int64
# NoOfSubDomain                   int64
# HasObfuscation                  int64
# NoOfObfuscatedChar              int64
# ObfuscationRatio              float64
# NoOfLettersInURL                int64
# LetterRatioInURL              float64
# NoOfDegitsInURL                 int64
# DegitRatioInURL               float64
# NoOfEqualsInURL                 int64
# NoOfQMarkInURL                  int64
# NoOfAmpersandInURL              int64
# NoOfOtherSpecialCharsInURL      int64
# SpacialCharRatioInURL         float64
# IsHTTPS                         int64
# LineOfCode                      int64
# LargestLineLength               int64
# HasTitle                        int64
# Title                          object
# DomainTitleMatchScore         float64
# URLTitleMatchScore            float64
# HasFavicon                      int64
# Robots                          int64
# IsResponsive                    int64
# NoOfURLRedirect                 int64
# NoOfSelfRedirect                int64
# HasDescription                  int64
# NoOfPopup                       int64
# NoOfiFrame                      int64
# HasExternalFormSubmit           int64
# HasSocialNet                    int64
# HasSubmitButton                 int64
# HasHiddenFields                 int64
# HasPasswordField                int64
# Bank                            int64
# Pay                             int64
# Crypto                          int64
# HasCopyrightInfo                int64
# NoOfImage                       int64
# NoOfCSS                         int64
# NoOfJS                          int64
# NoOfSelfRef                     int64
# NoOfEmptyRef                    int64
# NoOfExternalRef                 int64
# label                           int64
# dtype: object

# %%
import pandas as pd

def dataframe_summary(df):
    summary = pd.DataFrame({
        "DataType": df.dtypes,
        "Non-Null Count": df.count(),
        "Missing Values": df.isnull().sum(),
        "Unique Values": df.nunique(),
        "First Value": df.iloc[0],
        "Sample Values": df.apply(lambda x: x.unique()[:5])  # first 5 unique values
    })
    return summary

# Example usage
summary_table = dataframe_summary(df)
print(summary_table)
# Out:
#                            DataType  Non-Null Count  Missing Values  \
# URL                          object          235370               0
# URLLength                     int64          235370               0
# Domain                       object          235370               0
# DomainLength                  int64          235370               0
# IsDomainIP                    int64          235370               0
# TLD                          object          235370               0
# URLSimilarityIndex          float64          235370               0
# CharContinuationRate        float64          235370               0
# TLDLegitimateProb           float64          235370               0
# URLCharProb                 float64          235370               0
# TLDLength                     int64          235370               0
# NoOfSubDomain                 int64          235370               0
# HasObfuscation                int64          235370               0
# NoOfObfuscatedChar            int64          235370               0
# ObfuscationRatio            float64          235370               0
# NoOfLettersInURL              int64          235370               0
# LetterRatioInURL            float64          235370               0
# NoOfDegitsInURL               int64          235370               0
# DegitRatioInURL             float64          235370               0
# NoOfEqualsInURL               int64          235370               0
# NoOfQMarkInURL                int64          235370               0
# NoOfAmpersandInURL            int64          235370               0
# NoOfOtherSpecialCharsInURL    int64          235370               0
# SpacialCharRatioInURL       float64          235370               0
# IsHTTPS                       int64          235370               0
# LineOfCode                    int64          235370               0
# LargestLineLength             int64          235370               0
# HasTitle                      int64          235370               0
# Title                        object          235370               0
# DomainTitleMatchScore       float64          235370               0
# URLTitleMatchScore          float64          235370               0
# HasFavicon                    int64          235370               0
# Robots                        int64          235370               0
# IsResponsive                  int64          235370               0
# NoOfURLRedirect               int64          235370               0
# NoOfSelfRedirect              int64          235370               0
# HasDescription                int64          235370               0
# NoOfPopup                     int64          235370               0
# NoOfiFrame                    int64          235370               0
# HasExternalFormSubmit         int64          235370               0
# HasSocialNet                  int64          235370               0
# HasSubmitButton               int64          235370               0
# HasHiddenFields               int64          235370               0
# HasPasswordField              int64          235370               0
# Bank                          int64          235370               0
# Pay                           int64          235370               0
# Crypto                        int64          235370               0
# HasCopyrightInfo              int64          235370               0
# NoOfImage                     int64          235370               0
# NoOfCSS                       int64          235370               0
# NoOfJS                        int64          235370               0
# NoOfSelfRef                   int64          235370               0
# NoOfEmptyRef                  int64          235370               0
# NoOfExternalRef               int64          235370               0
# label                         int64          235370               0
#
#                             Unique Values  \
# URL                                235370
# URLLength                             482
# Domain                             220086
# DomainLength                          101
# IsDomainIP                              2
# TLD                                   695
# URLSimilarityIndex                  36350
# CharContinuationRate                  898
# TLDLegitimateProb                     465
# URLCharProb                        227293
# TLDLength                              12
# NoOfSubDomain                          10
# HasObfuscation                          2
# NoOfObfuscatedChar                     20
# ObfuscationRatio                      146
# NoOfLettersInURL                      421
# LetterRatioInURL                      709
# NoOfDegitsInURL                       182
# DegitRatioInURL                       575
# NoOfEqualsInURL                        25
# NoOfQMarkInURL                          5
# NoOfAmpersandInURL                     31
# NoOfOtherSpecialCharsInURL             74
# SpacialCharRatioInURL                 240
# IsHTTPS                                 2
# LineOfCode                          10738
# LargestLineLength                   26178
# HasTitle                                2
# Title                              197782
# DomainTitleMatchScore                 152
# URLTitleMatchScore                    497
# HasFavicon                              2
# Robots                                  2
# IsResponsive                            2
# NoOfURLRedirect                         2
# NoOfSelfRedirect                        2
# HasDescription                          2
# NoOfPopup                             115
# NoOfiFrame                            119
# HasExternalFormSubmit                   2
# HasSocialNet                            2
# HasSubmitButton                         2
# HasHiddenFields                         2
# HasPasswordField                        2
# Bank                                    2
# Pay                                     2
# Crypto                                  2
# HasCopyrightInfo                        2
# NoOfImage                             992
# NoOfCSS                               209
# NoOfJS                                253
# NoOfSelfRef                          1374
# NoOfEmptyRef                          296
# NoOfExternalRef                      1191
# label                                   2
#
#                                                                   First Value  \
# URL                                          https://www.southbankmosaics.com
# URLLength                                                                  31
# Domain                                               www.southbankmosaics.com
# DomainLength                                                               24
# IsDomainIP                                                                  0
# TLD                                                                       com
# URLSimilarityIndex                                                      100.0
# CharContinuationRate                                                      1.0
# TLDLegitimateProb                                                    0.522907
# URLCharProb                                                          0.061933
# TLDLength                                                                   3
# NoOfSubDomain                                                               1
# HasObfuscation                                                              0
# NoOfObfuscatedChar                                                          0
# ObfuscationRatio                                                          0.0
# NoOfLettersInURL                                                           18
# LetterRatioInURL                                                        0.581
# NoOfDegitsInURL                                                             0
# DegitRatioInURL                                                           0.0
# NoOfEqualsInURL                                                             0
# NoOfQMarkInURL                                                              0
# NoOfAmpersandInURL                                                          0
# NoOfOtherSpecialCharsInURL                                                  1
# SpacialCharRatioInURL                                                   0.032
# IsHTTPS                                                                     1
# LineOfCode                                                                558
# LargestLineLength                                                        9381
# HasTitle                                                                    1
# Title                       à¸‚à¹ˆà¸²à¸§à¸ªà¸” à¸‚à¹ˆà¸²à¸§à¸§à¸±à¸™à¸™à¸µ...
# DomainTitleMatchScore                                                     0.0
# URLTitleMatchScore                                                        0.0
# HasFavicon                                                                  0
# Robots                                                                      1
# IsResponsive                                                                1
# NoOfURLRedirect                                                             0
# NoOfSelfRedirect                                                            0
# HasDescription                                                              0
# NoOfPopup                                                                   0
# NoOfiFrame                                                                  1
# HasExternalFormSubmit                                                       0
# HasSocialNet                                                                0
# HasSubmitButton                                                             1
# HasHiddenFields                                                             1
# HasPasswordField                                                            0
# Bank                                                                        1
# Pay                                                                         0
# Crypto                                                                      0
# HasCopyrightInfo                                                            1
# NoOfImage                                                                  34
# NoOfCSS                                                                    20
# NoOfJS                                                                     28
# NoOfSelfRef                                                               119
# NoOfEmptyRef                                                                0
# NoOfExternalRef                                                           124
# label                                                                       1
#
#                                                                 Sample Values
# URL                         [https://www.southbankmosaics.com, https://www...
# URLLength                                                [31, 23, 29, 26, 33]
# Domain                      [www.southbankmosaics.com, www.uni-mainz.de, w...
# DomainLength                                             [24, 16, 22, 19, 26]
# IsDomainIP                                                             [0, 1]
# TLD                                                    [com, de, uk, org, in]
# URLSimilarityIndex          [100.0, 82.6446281, 55.28492647, 56.55114117, ...
# CharContinuationRate        [1.0, 0.666666667, 0.866666667, 0.625, 0.92307...
# TLDLegitimateProb           [0.5229071, 0.0326503, 0.028555, 0.0799628, 0....
# URLCharProb                 [0.061933179, 0.050207214, 0.06412872, 0.05760...
# TLDLength                                                     [3, 2, 4, 5, 6]
# NoOfSubDomain                                                 [1, 2, 3, 0, 5]
# HasObfuscation                                                         [0, 1]
# NoOfObfuscatedChar                                          [0, 9, 3, 15, 18]
# ObfuscationRatio                            [0.0, 0.098, 0.024, 0.016, 0.053]
# NoOfLettersInURL                                          [18, 9, 15, 13, 20]
# LetterRatioInURL                            [0.581, 0.391, 0.517, 0.5, 0.606]
# NoOfDegitsInURL                                              [0, 2, 7, 4, 12]
# DegitRatioInURL                               [0.0, 0.1, 0.269, 0.062, 0.154]
# NoOfEqualsInURL                                               [0, 1, 2, 3, 5]
# NoOfQMarkInURL                                                [0, 1, 3, 2, 4]
# NoOfAmpersandInURL                                           [0, 3, 1, 2, 15]
# NoOfOtherSpecialCharsInURL                                   [1, 2, 3, 5, 11]
# SpacialCharRatioInURL                      [0.032, 0.087, 0.069, 0.038, 0.03]
# IsHTTPS                                                                [1, 0]
# LineOfCode                                        [558, 618, 467, 6356, 6089]
# LargestLineLength                              [9381, 682, 26824, 28404, 737]
# HasTitle                                                               [1, 0]
# Title                       [à¸‚à¹ˆà¸²à¸§à¸ªà¸” à¸‚à¹ˆà¸²à¸§à¸§à¸±à¸™à¸™à¸...
# DomainTitleMatchScore            [0.0, 55.55555556, 46.66666667, 100.0, 50.0]
# URLTitleMatchScore               [0.0, 55.55555556, 46.66666667, 100.0, 50.0]
# HasFavicon                                                             [0, 1]
# Robots                                                                 [1, 0]
# IsResponsive                                                           [1, 0]
# NoOfURLRedirect                                                        [0, 1]
# NoOfSelfRedirect                                                       [0, 1]
# HasDescription                                                         [0, 1]
# NoOfPopup                                                    [0, 1, 2, 12, 3]
# NoOfiFrame                                                   [1, 0, 12, 2, 4]
# HasExternalFormSubmit                                                  [0, 1]
# HasSocialNet                                                           [0, 1]
# HasSubmitButton                                                        [1, 0]
# HasHiddenFields                                                        [1, 0]
# HasPasswordField                                                       [0, 1]
# Bank                                                                   [1, 0]
# Pay                                                                    [0, 1]
# Crypto                                                                 [0, 1]
# HasCopyrightInfo                                                       [1, 0]
# NoOfImage                                                [34, 50, 10, 3, 244]
# NoOfCSS                                                    [20, 9, 2, 27, 15]
# NoOfJS                                                     [28, 8, 7, 15, 34]
# NoOfSelfRef                                             [119, 39, 42, 22, 72]
# NoOfEmptyRef                                                 [0, 2, 1, 6, 12]
# NoOfExternalRef                                         [124, 217, 5, 31, 85]
# label                                                                  [1, 0]

# %%
X = df.drop(columns =["URL","label"])
y = df['label']

# %% [markdown]
# # Relation between independent and dependent variables

# %%
numeric_features = X.select_dtypes(include=['int64', 'float64'])

# Compute correlation with target
corr = numeric_features.corrwith(y)

# Show top 10 features most correlated
print(corr.sort_values(ascending=False).head(10))

# Optional: heatmap of all correlations
plt.figure(figsize=(12,8))
sns.heatmap(numeric_features.corr(), annot=False, cmap='coolwarm')
plt.title("Feature Correlation Matrix")
plt.show()
# Out:
# URLSimilarityIndex       0.860342
# HasSocialNet             0.783882
# HasCopyrightInfo         0.743197
# HasDescription           0.690011
# IsHTTPS                  0.610253
# DomainTitleMatchScore    0.584204
# HasSubmitButton          0.578816
# IsResponsive             0.548977
# URLTitleMatchScore       0.538844
# HasHiddenFields          0.507715
# dtype: float64

# %%
# Example: check counts per category for the label
pd.crosstab(X['TLD'], y)
# Out:
# label    0    1
# TLD
# 100      1    0
# 101      2    0
# 103     24    0
# 106      5    0
# 107      1    0
# ...    ...  ...
# yt       2    0
# za     131  377
# zm       4    9
# zone    13    1
# zw      18   21
#
# [695 rows x 2 columns]

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, ex = chi2_contingency(pd.crosstab(X['TLD'], y))
print("p-value:", p)
# Out:
# p-value: 0.0

# %%
sns.countplot(x='TLD', hue=y, data=X.join(y))
plt.show()

# %%
object_features = df.select_dtypes(include=['object'])

object_features.nunique()
# Out:
# URL       235370
# Domain    220086
# TLD          695
# Title     197782
# dtype: int64

# %%
X = X.drop(columns =['Domain','Title'])

# %%
common = ['com', 'net', 'org']
country_codes = ['uk', 'in', 'us', 'de', 'fr']  # add more if you want

def tld_group(tld):
    if tld in common:
        return 'common'
    elif tld in country_codes:
        return 'country'
    else:
        return 'rare'

X['TLD_group'] = X['TLD'].apply(tld_group)
X = pd.get_dummies(X, columns=['TLD_group'])
X = X.drop(columns=['TLD'])  # drop original

# %%
X
# Out:
#         URLLength  DomainLength  IsDomainIP  URLSimilarityIndex  \
# 0              31            24           0          100.000000
# 1              23            16           0          100.000000
# 2              29            22           0          100.000000
# 3              26            19           0          100.000000
# 4              33            26           0          100.000000
# ...           ...           ...         ...                 ...
# 235790         29            22           0          100.000000
# 235791         28            21           0          100.000000
# 235792         30            23           0          100.000000
# 235793         55            47           0           28.157537
# 235794         33            26           0          100.000000
#
#         CharContinuationRate  TLDLegitimateProb  URLCharProb  TLDLength  \
# 0                   1.000000           0.522907     0.061933          3
# 1                   0.666667           0.032650     0.050207          2
# 2                   0.866667           0.028555     0.064129          2
# 3                   1.000000           0.522907     0.057606          3
# 4                   1.000000           0.079963     0.059441          3
# ...                      ...                ...          ...        ...
# 235790              1.000000           0.522907     0.058739          3
# 235791              0.785714           0.028555     0.053834          2
# 235792              1.000000           0.003319     0.063093          2
# 235793              0.465116           0.000961     0.050211          3
# 235794              1.000000           0.522907     0.060596          3
#
#         NoOfSubDomain  HasObfuscation  ...  HasCopyrightInfo  NoOfImage  \
# 0                   1               0  ...                 1         34
# 1                   1               0  ...                 1         50
# 2                   2               0  ...                 1         10
# 3                   1               0  ...                 1          3
# 4                   1               0  ...                 1        244
# ...               ...             ...  ...               ...        ...
# 235790              1               0  ...                 1         51
# 235791              2               0  ...                 0         50
# 235792              1               0  ...                 1         27
# 235793              2               0  ...                 0          0
# 235794              1               0  ...                 1         21
#
#         NoOfCSS  NoOfJS  NoOfSelfRef  NoOfEmptyRef  NoOfExternalRef  \
# 0            20      28          119             0              124
# 1             9       8           39             0              217
# 2             2       7           42             2                5
# 3            27      15           22             1               31
# 4            15      34           72             1               85
# ...         ...     ...          ...           ...              ...
# 235790        7      21          187             2              191
# 235791        1       7           88             0               31
# 235792       10      30           58             2               67
# 235793        0       3            0             0                0
# 235794        6      18          256             0              261
#
#         TLD_group_common  TLD_group_country  TLD_group_rare
# 0                   True              False           False
# 1                  False               True           False
# 2                  False               True           False
# 3                   True              False           False
# 4                   True              False           False
# ...                  ...                ...             ...
# 235790              True              False           False
# 235791             False               True           False
# 235792             False              False            True
# 235793             False              False            True
# 235794              True              False           False
#
# [235370 rows x 53 columns]

# %%
X.dtypes
# Out:
# URLLength                       int64
# DomainLength                    int64
# IsDomainIP                      int64
# URLSimilarityIndex            float64
# CharContinuationRate          float64
# TLDLegitimateProb             float64
# URLCharProb                   float64
# TLDLength                       int64
# NoOfSubDomain                   int64
# HasObfuscation                  int64
# NoOfObfuscatedChar              int64
# ObfuscationRatio              float64
# NoOfLettersInURL                int64
# LetterRatioInURL              float64
# NoOfDegitsInURL                 int64
# DegitRatioInURL               float64
# NoOfEqualsInURL                 int64
# NoOfQMarkInURL                  int64
# NoOfAmpersandInURL              int64
# NoOfOtherSpecialCharsInURL      int64
# SpacialCharRatioInURL         float64
# IsHTTPS                         int64
# LineOfCode                      int64
# LargestLineLength               int64
# HasTitle                        int64
# DomainTitleMatchScore         float64
# URLTitleMatchScore            float64
# HasFavicon                      int64
# Robots                          int64
# IsResponsive                    int64
# NoOfURLRedirect                 int64
# NoOfSelfRedirect                int64
# HasDescription                  int64
# NoOfPopup                       int64
# NoOfiFrame                      int64
# HasExternalFormSubmit           int64
# HasSocialNet                    int64
# HasSubmitButton                 int64
# HasHiddenFields                 int64
# HasPasswordField                int64
# Bank                            int64
# Pay                             int64
# Crypto                          int64
# HasCopyrightInfo                int64
# NoOfImage                       int64
# NoOfCSS                         int64
# NoOfJS                          int64
# NoOfSelfRef                     int64
# NoOfEmptyRef                    int64
# NoOfExternalRef                 int64
# TLD_group_common                 bool
# TLD_group_country                bool
# TLD_group_rare                   bool
# dtype: object

# %% [markdown]
# We are gonna do k-fold stratified classification..

# %% [markdown]
# # Model build:

# %% [markdown]
# Step 1: Stratified K-Fold Initialization

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from xgboost import XGBClassifier

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# Step 2: Model Initialization

# %%
model = XGBClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    use_label_encoder=False,
    eval_metric="logloss"
)

# %% [markdown]
# Step 3: Loop Through Folds

# %%
accuracy_scores = []
f1_scores = []
precision_scores = []
recall_scores = []

# %%
for train_idx, test_idx in skf.split(X, y):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    # Train
    model.fit(X_train, y_train)

    # Predict
    y_pred = model.predict(X_test)

    # Evaluate
    accuracy_scores.append(accuracy_score(y_test, y_pred))
    f1_scores.append(f1_score(y_test, y_pred))
    precision_scores.append(precision_score(y_test, y_pred))
    recall_scores.append(recall_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:44:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:44:24] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:44:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:44:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:44:47] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
print("✅ XGBoost with Stratified 5-Fold CV")
print(f"Accuracy:  {np.mean(accuracy_scores):.4f} ± {np.std(accuracy_scores):.4f}")
print(f"F1 Score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"Precision: {np.mean(precision_scores):.4f} ± {np.std(precision_scores):.4f}")
print(f"Recall:    {np.mean(recall_scores):.4f} ± {np.std(recall_scores):.4f}")
# Out:
# ✅ XGBoost with Stratified 5-Fold CV
# Accuracy:  1.0000 ± 0.0000
# F1 Score:  1.0000 ± 0.0000
# Precision: 1.0000 ± 0.0000
# Recall:    1.0000 ± 0.0000

# %%
for col in X.columns:
    correlation = X[col].corr(y)
    if abs(correlation) > 0.99:  # suspiciously high
        print(col, correlation)

# %% [markdown]
# # Only using normal train_test_split:

# %%
from sklearn.model_selection import train_test_split

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
model1 = XGBClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    use_label_encoder=False,
    eval_metric="logloss"
)

# %%
model1.fit(X_train1,y_train1)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:50:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred1 = model.predict(X_test1)

# %%
accuracy_score1 = accuracy_score(y_test1, y_pred1)

# %%
accuracy_score1
# Out:
# 1.0

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(model, max_num_features=20, importance_type='gain')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=15,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42,
    n_jobs=-1
)

# %%
model_rf = rf_model.fit(X_train1,y_train1)

# %%
y_pred_rf = model_rf.predict(X_test1)

# %%
accuracy_rf = accuracy_score(y_test1, y_pred_rf)

# %%
accuracy_rf
# Out:
# 0.9999575137018312

# %%
rf_model2 = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42,
    n_jobs=-1
)

# %%
model_rf_2 = rf_model2.fit(X_train1,y_train1)

# %%
y_pred_rf_2 = model_rf_2.predict(X_test1)

# %%
accuracy_rf2 = accuracy_score(y_pred_rf_2,y_test1)

# %%
accuracy_rf2
# Out:
# 0.9999787568509155

# %%
print("f1_score :",f1_score(y_test1, y_pred_rf_2))
print("recall :",recall_score(y_test1, y_pred_rf_2))
print("precision :",precision_score(y_test1, y_pred_rf_2))
# Out:
# f1_score : 0.9999814612261545
# recall : 1.0
# precision : 0.9999629231396685

# %%
for col in X.columns:
    print(col, X[col].nunique())
# Out:
# URLLength 482
# DomainLength 101
# IsDomainIP 2
# URLSimilarityIndex 36350
# CharContinuationRate 898
# TLDLegitimateProb 465
# URLCharProb 227293
# TLDLength 12
# NoOfSubDomain 10
# HasObfuscation 2
# NoOfObfuscatedChar 20
# ObfuscationRatio 146
# NoOfLettersInURL 421
# LetterRatioInURL 709
# NoOfDegitsInURL 182
# DegitRatioInURL 575
# NoOfEqualsInURL 25
# NoOfQMarkInURL 5
# NoOfAmpersandInURL 31
# NoOfOtherSpecialCharsInURL 74
# SpacialCharRatioInURL 240
# IsHTTPS 2
# LineOfCode 10738
# LargestLineLength 26178
# HasTitle 2
# DomainTitleMatchScore 152
# URLTitleMatchScore 497
# HasFavicon 2
# Robots 2
# IsResponsive 2
# NoOfURLRedirect 2
# NoOfSelfRedirect 2
# HasDescription 2
# NoOfPopup 115
# NoOfiFrame 119
# HasExternalFormSubmit 2
# HasSocialNet 2
# HasSubmitButton 2
# HasHiddenFields 2
# HasPasswordField 2
# Bank 2
# Pay 2
# Crypto 2
# HasCopyrightInfo 2
# NoOfImage 992
# NoOfCSS 209
# NoOfJS 253
# NoOfSelfRef 1374
# NoOfEmptyRef 296
# NoOfExternalRef 1191
# TLD_group_common 2
# TLD_group_country 2
# TLD_group_rare 2

# %%
X.hist(figsize=(20,15), bins=50)
plt.show()

# %%
df_numeric = df.select_dtypes(include=['number'])

corr_matrix = df_numeric.corr()
corr_matrix.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_1959d_row0_col0, #T_1959d_row1_col1, #T_1959d_row2_col2, #T_1959d_row3_col3, #T_1959d_row4_col4, #T_1959d_row5_col5, #T_1959d_row6_col6, #T_1959d_row7_col7, #T_1959d_row8_col8, #T_1959d_row9_col9, #T_1959d_row10_col10, #T_1959d_row11_col11, #T_1959d_row12_col12, #T_1959d_row13_col13, #T_1959d_row14_col14, #T_1959d_row15_col15, #T_1959d_row16_col16, #T_1959d_row17_col17, #T_1959d_row18_col18, #T_1959d_row19_col19, #T_1959d_row20_col20, #T_1959d_row21_col21, #T_1959d_row22_col22, #T_1959d_row23_col23, #T_1959d_row24_col24, #T_1959d_row25_col25, #T_1959d_row26_col26, #T_1959d_row27_col27, #T_1959d_row28_col28, #T_1959d_row29_col29, #T_1959d_row30_col30, #T_1959d_row31_col31, #T_1959d_row32_col32, #T_1959d_row33_col33, #T_1959d_row34_col34, #T_1959d_row35_col35, #T_1959d_row36_col36, #T_1959d_row37_col37, #T_1959d_row38_col38, #T_1959d_row39_col39, #T_1959d_row40_col40, #T_1959d_row41_col41, #T_1959d_row42_col42, #T_1959d_row43_col43, #T_1959d_row44_col44, #T_1959d_row45_col45, #T_1959d_row46_col46, #T_1959d_row47_col47, #T_1959d_row48_col48, #T_1959d_row49_col49, #T_1959d_row50_col50 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col1, #T_1959d_row3_col38, #T_1959d_row13_col0, #T_1959d_row19_col13, #T_1959d_row20_col8, #T_1959d_row27_col26, #T_1959d_row28_col4, #T_1959d_row28_col25, #T_1959d_row46_col6, #T_1959d_row49_col50 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_1959d_row0_col2, #T_1959d_row2_col4, #T_1959d_row9_col13, #T_1959d_row10_col3, #T_1959d_row10_col9, #T_1959d_row21_col15, #T_1959d_row26_col28, #T_1959d_row33_col1, #T_1959d_row34_col15, #T_1959d_row34_col38, #T_1959d_row40_col34 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_1959d_row0_col3, #T_1959d_row0_col23, #T_1959d_row0_col31, #T_1959d_row1_col3, #T_1959d_row2_col22, #T_1959d_row2_col44, #T_1959d_row4_col42, #T_1959d_row6_col39, #T_1959d_row8_col26, #T_1959d_row9_col44, #T_1959d_row10_col21, #T_1959d_row11_col31, #T_1959d_row12_col23, #T_1959d_row13_col21, #T_1959d_row13_col23, #T_1959d_row14_col29, #T_1959d_row14_col46, #T_1959d_row16_col34, #T_1959d_row18_col31, #T_1959d_row18_col49, #T_1959d_row19_col50, #T_1959d_row20_col23, #T_1959d_row21_col48, #T_1959d_row22_col7, #T_1959d_row25_col8, #T_1959d_row25_col13, #T_1959d_row25_col14, #T_1959d_row28_col7, #T_1959d_row34_col30, #T_1959d_row39_col31, #T_1959d_row41_col30, #T_1959d_row42_col31, #T_1959d_row44_col7, #T_1959d_row46_col16, #T_1959d_row47_col31, #T_1959d_row48_col35, #T_1959d_row49_col39 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col4, #T_1959d_row8_col17, #T_1959d_row10_col17, #T_1959d_row16_col3, #T_1959d_row17_col25, #T_1959d_row17_col26, #T_1959d_row21_col44, #T_1959d_row29_col22, #T_1959d_row30_col43, #T_1959d_row34_col12, #T_1959d_row38_col40, #T_1959d_row39_col5, #T_1959d_row40_col0, #T_1959d_row44_col28, #T_1959d_row44_col45, #T_1959d_row49_col41 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_1959d_row0_col5, #T_1959d_row3_col40, #T_1959d_row9_col5, #T_1959d_row14_col11, #T_1959d_row14_col36, #T_1959d_row14_col43, #T_1959d_row17_col36, #T_1959d_row18_col38, #T_1959d_row32_col35, #T_1959d_row46_col39, #T_1959d_row48_col28, #T_1959d_row48_col34, #T_1959d_row49_col34 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col6, #T_1959d_row1_col7, #T_1959d_row5_col37, #T_1959d_row6_col8, #T_1959d_row6_col24, #T_1959d_row8_col43, #T_1959d_row9_col36, #T_1959d_row14_col26, #T_1959d_row18_col32, #T_1959d_row22_col21, #T_1959d_row27_col1, #T_1959d_row29_col44, #T_1959d_row35_col0, #T_1959d_row38_col49, #T_1959d_row40_col46, #T_1959d_row44_col21, #T_1959d_row46_col19, #T_1959d_row46_col34, #T_1959d_row49_col27 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_1959d_row0_col7, #T_1959d_row0_col37, #T_1959d_row8_col27, #T_1959d_row10_col28, #T_1959d_row13_col25, #T_1959d_row17_col18, #T_1959d_row20_col9, #T_1959d_row23_col46, #T_1959d_row25_col40, #T_1959d_row26_col12, #T_1959d_row27_col35, #T_1959d_row28_col34, #T_1959d_row30_col39, #T_1959d_row32_col13, #T_1959d_row33_col44, #T_1959d_row33_col49, #T_1959d_row36_col0, #T_1959d_row41_col42, #T_1959d_row44_col48, #T_1959d_row45_col47 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col8, #T_1959d_row3_col47, #T_1959d_row10_col1, #T_1959d_row12_col18, #T_1959d_row16_col13, #T_1959d_row26_col27, #T_1959d_row28_col21, #T_1959d_row28_col46, #T_1959d_row33_col26, #T_1959d_row35_col32, #T_1959d_row37_col47, #T_1959d_row39_col20, #T_1959d_row40_col20, #T_1959d_row40_col38, #T_1959d_row48_col36 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_1959d_row0_col9, #T_1959d_row1_col5, #T_1959d_row5_col29, #T_1959d_row6_col44, #T_1959d_row7_col14, #T_1959d_row7_col32, #T_1959d_row13_col4, #T_1959d_row22_col40, #T_1959d_row24_col44, #T_1959d_row29_col40, #T_1959d_row31_col43, #T_1959d_row32_col15, #T_1959d_row35_col5, #T_1959d_row38_col35, #T_1959d_row39_col24, #T_1959d_row43_col1, #T_1959d_row43_col39, #T_1959d_row46_col0, #T_1959d_row47_col5, #T_1959d_row49_col24, #T_1959d_row50_col40 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col10, #T_1959d_row5_col7, #T_1959d_row44_col22, #T_1959d_row50_col46 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_1959d_row0_col11, #T_1959d_row5_col27, #T_1959d_row9_col38, #T_1959d_row10_col38, #T_1959d_row14_col32, #T_1959d_row19_col11, #T_1959d_row21_col39, #T_1959d_row22_col14, #T_1959d_row23_col38, #T_1959d_row31_col24, #T_1959d_row32_col19, #T_1959d_row32_col20, #T_1959d_row36_col39, #T_1959d_row44_col14, #T_1959d_row45_col27 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col12, #T_1959d_row12_col0 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col13, #T_1959d_row0_col18, #T_1959d_row2_col19, #T_1959d_row18_col12, #T_1959d_row19_col1, #T_1959d_row29_col4 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_1959d_row0_col14 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col15, #T_1959d_row21_col3, #T_1959d_row46_col50 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_1959d_row0_col16, #T_1959d_row12_col14, #T_1959d_row14_col10, #T_1959d_row25_col50 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_1959d_row0_col17, #T_1959d_row12_col13, #T_1959d_row19_col17, #T_1959d_row26_col6, #T_1959d_row29_col32, #T_1959d_row32_col6 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_1959d_row0_col19, #T_1959d_row36_col50 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col20, #T_1959d_row3_col29, #T_1959d_row13_col19, #T_1959d_row27_col25, #T_1959d_row29_col24, #T_1959d_row41_col36, #T_1959d_row50_col24 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_1959d_row0_col21, #T_1959d_row0_col38, #T_1959d_row2_col7, #T_1959d_row2_col24, #T_1959d_row5_col16, #T_1959d_row9_col24, #T_1959d_row11_col24, #T_1959d_row12_col21, #T_1959d_row13_col9, #T_1959d_row17_col29, #T_1959d_row18_col47, #T_1959d_row23_col34, #T_1959d_row26_col42, #T_1959d_row27_col42, #T_1959d_row29_col48, #T_1959d_row30_col2, #T_1959d_row31_col27, #T_1959d_row38_col7, #T_1959d_row38_col16, #T_1959d_row40_col16, #T_1959d_row40_col48, #T_1959d_row48_col16, #T_1959d_row50_col0, #T_1959d_row50_col12 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_1959d_row0_col22, #T_1959d_row0_col47, #T_1959d_row1_col30, #T_1959d_row1_col39, #T_1959d_row2_col23, #T_1959d_row2_col35, #T_1959d_row3_col31, #T_1959d_row4_col19, #T_1959d_row5_col9, #T_1959d_row7_col23, #T_1959d_row7_col39, #T_1959d_row7_col42, #T_1959d_row8_col11, #T_1959d_row9_col23, #T_1959d_row9_col35, #T_1959d_row10_col39, #T_1959d_row11_col23, #T_1959d_row11_col35, #T_1959d_row14_col39, #T_1959d_row15_col10, #T_1959d_row16_col23, #T_1959d_row16_col39, #T_1959d_row18_col23, #T_1959d_row18_col30, #T_1959d_row18_col35, #T_1959d_row18_col39, #T_1959d_row23_col11, #T_1959d_row23_col42, #T_1959d_row28_col45, #T_1959d_row29_col45, #T_1959d_row30_col11, #T_1959d_row31_col35, #T_1959d_row33_col39, #T_1959d_row33_col40, #T_1959d_ro

# %%
correlation_with_target = corr_matrix["label"].drop("label") #extracts the column of correlations between all features and the target variable (label)
print("Correlation with target:\n", correlation_with_target)
# Out:
# Correlation with target:
#  URLLength                    -0.233060
# DomainLength                 -0.282643
# IsDomainIP                   -0.060289
# URLSimilarityIndex            0.860342
# CharContinuationRate          0.467162
# TLDLegitimateProb             0.097229
# URLCharProb                   0.469521
# TLDLength                    -0.078973
# NoOfSubDomain                -0.006356
# HasObfuscation               -0.052522
# NoOfObfuscatedChar           -0.015345
# ObfuscationRatio             -0.041954
# NoOfLettersInURL             -0.257626
# LetterRatioInURL             -0.366970
# NoOfDegitsInURL              -0.177755
# DegitRatioInURL              -0.431896
# NoOfEqualsInURL              -0.077165
# NoOfQMarkInURL               -0.176027
# NoOfAmpersandInURL           -0.034698
# NoOfOtherSpecialCharsInURL   -0.358268
# SpacialCharRatioInURL        -0.533003
# IsHTTPS                       0.610253
# LineOfCode                    0.271970
# LargestLineLength            -0.040974
# HasTitle                      0.460337
# DomainTitleMatchScore         0.584204
# URLTitleMatchScore            0.538844
# HasFavicon                    0.493607
# Robots                        0.392461
# IsResponsive                  0.548977
# NoOfURLRedirect              -0.046398
# NoOfSelfRedirect             -0.076774
# HasDescription                0.690011
# NoOfPopup                     0.047355
# NoOfiFrame                    0.225567
# HasExternalFormSubmit         0.167398
# HasSocialNet                  0.783882
# HasSubmitButton               0.578816
# HasHiddenFields               0.507715
# HasPasswordField              0.139162
# Bank                          0.188886
# Pay                           0.359724
# Crypto                        0.099656
# HasCopyrightInfo              0.743197
# NoOfImage                     0.274365
# NoOfCSS                       0.068035
# NoOfJS                        0.373162
# NoOfSelfRef                   0.315867
# NoOfEmptyRef                  0.109138
# NoOfExternalRef               0.258339
# Name: label, dtype: float64

# %%
# Identify features with low correlation to the target (e.g., abs(correlation) < 0.5)
low_correlation_features = correlation_with_target[correlation_with_target.abs() < 0.5].index.tolist()

#abs() method in Python is used to calculate the absolute value of numbers. In the context of a Pandas Series or DataFrame, it
#computes the absolute value of each element, ensuring all values are non-negative.

print("Low correlation features:", low_correlation_features)
# Out:
# Low correlation features: ['URLLength', 'DomainLength', 'IsDomainIP', 'CharContinuationRate', 'TLDLegitimateProb', 'URLCharProb', 'TLDLength', 'NoOfSubDomain', 'HasObfuscation', 'NoOfObfuscatedChar', 'ObfuscationRatio', 'NoOfLettersInURL', 'LetterRatioInURL', 'NoOfDegitsInURL', 'DegitRatioInURL', 'NoOfEqualsInURL', 'NoOfQMarkInURL', 'NoOfAmpersandInURL', 'NoOfOtherSpecialCharsInURL', 'LineOfCode', 'LargestLineLength', 'HasTitle', 'HasFavicon', 'Robots', 'NoOfURLRedirect', 'NoOfSelfRedirect', 'NoOfPopup', 'NoOfiFrame', 'HasExternalFormSubmit', 'HasPasswordField', 'Bank', 'Pay', 'Crypto', 'NoOfImage', 'NoOfCSS', 'NoOfJS', 'NoOfSelfRef', 'NoOfEmptyRef', 'NoOfExternalRef']

# %%
new_X = df.drop(columns= ['URL','Domain','Title','URLLength', 'DomainLength', 'IsDomainIP', 'CharContinuationRate', 'TLDLegitimateProb', 'URLCharProb', 'TLDLength', 'NoOfSubDomain', 'HasObfuscation', 'NoOfObfuscatedChar', 'ObfuscationRatio', 'NoOfLettersInURL', 'LetterRatioInURL', 'NoOfDegitsInURL', 'DegitRatioInURL', 'NoOfEqualsInURL', 'NoOfQMarkInURL', 'NoOfAmpersandInURL', 'NoOfOtherSpecialCharsInURL', 'LineOfCode', 'LargestLineLength', 'HasTitle', 'HasFavicon', 'Robots', 'NoOfURLRedirect', 'NoOfSelfRedirect', 'NoOfPopup', 'NoOfiFrame', 'HasExternalFormSubmit', 'HasPasswordField', 'Bank', 'Pay', 'Crypto', 'NoOfImage', 'NoOfCSS', 'NoOfJS', 'NoOfSelfRef', 'NoOfEmptyRef', 'NoOfExternalRef','label'])

# %%
new_y = df['label']

# %%
new_X.dtypes
# Out:
# TLD                       object
# URLSimilarityIndex       float64
# SpacialCharRatioInURL    float64
# IsHTTPS                    int64
# DomainTitleMatchScore    float64
# URLTitleMatchScore       float64
# IsResponsive               int64
# HasDescription             int64
# HasSocialNet               int64
# HasSubmitButton            int64
# HasHiddenFields            int64
# HasCopyrightInfo           int64
# dtype: object

# %%
new_X['TLD'].nunique()
# Out:
# 695

# %%
common = ['com', 'net', 'org']
country_codes = ['uk', 'in', 'us', 'de', 'fr']  # add more if you want

def tld_group(tld):
    if tld in common:
        return 'common'
    elif tld in country_codes:
        return 'country'
    else:
        return 'rare'

new_X['TLD_group'] = new_X['TLD'].apply(tld_group)
new_X = pd.get_dummies(new_X, columns=['TLD_group'])
new_X = new_X.drop(columns=['TLD'])  # drop original

# %%
X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb = train_test_split(
    new_X, new_y, test_size=0.2, stratify=y, random_state=42
)

# %%
xgb_model = XGBClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    use_label_encoder=False,
    eval_metric="logloss"
)

# %%
xgb_model = xgb_model.fit(X_train_xgb,y_train_xgb)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [21:59:39] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
y_pred_xgb = xgb_model.predict(X_test_xgb)

# %%
print("Accuracy : ",accuracy_score(y_test_xgb,y_pred_xgb))
print("F1-score : ",f1_score(y_test_xgb, y_pred_xgb))
print("Recall : ",recall_score(y_test_xgb,y_pred_xgb))
print("Precision : ",precision_score(y_test_xgb,y_pred_xgb))
# Out:
# Accuracy :  0.9998725411054935
# F1-score :  0.9998887776665555
# Recall :  1.0
# Precision :  0.9997775800711743

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm = confusion_matrix(y_pred_xgb, y_test_xgb)
print(cm)
# Out:
# [[20098     0]
#  [    6 26970]]

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 0', 'Class 1'])
disp.plot(cmap=plt.cm.Blues)  # Optional: color map
plt.show()

# %%
X_test_xgb.shape
# Out:
# (47074, 14)

# %%
import xgboost as xgb
from xgboost import plot_tree
import matplotlib.pyplot as plt

# Assuming your model is trained as `model`
plt.figure(figsize=(20,10))  # increase size for readability
plot_tree(xgb_model, num_trees=0)  # num_trees=0 means the first tree
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/plotting.py:267: FutureWarning: The `num_trees` parameter is deprecated, use `tree_idx` insetad.
#   warnings.warn(

# %%
from xgboost import plot_importance

plt.figure(figsize=(10,6))
plot_importance(xgb_model, importance_type='weight')  # or 'gain', 'cover'
plt.show()

# %%
import xgboost as xgb

xgb.to_graphviz(xgb_model, num_trees=0)  # requires graphviz installed
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/plotting.py:267: FutureWarning: The `num_trees` parameter is deprecated, use `tree_idx` insetad.
#   warnings.warn(
